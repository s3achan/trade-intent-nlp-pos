# %%
from datasets import load_dataset
import re
import nltk

from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.corpus import stopwords
from collections import defaultdict
from collections import Counter
import pandas as pd
import warnings
warnings.filterwarnings("ignore")

# %%
ds = load_dataset("HugoGiddins/buy_sell_intent")
ds
# Out:
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# DatasetDict({
#     test: Dataset({
#         features: ['post_id', 'subject_type', 'subject_identifier', 'subject_name', 'content', 'sarcasm', 'relevance', 'polarity', 'label_11', 'label_index', 'confidence'],
#         num_rows: 940
#     })
# })

# %%
df = ds["test"].to_pandas()

# %%
df.shape
# Out:
# (940, 11)

# %%
df.iloc[1]
# Out:
# post_id                                                       real_7500
# subject_type                                                      token
# subject_identifier                                                   OP
# subject_name                                                   Optimism
# content               GM chat! ... 🧡 I want to start this day with s...
# sarcasm                                                               0
# relevance                                                             1
# polarity                                                       positive
# label_11                                                        bullish
# label_index                                                           8
# confidence                                                          0.9
# Name: 1, dtype: object

# %% [markdown]
# **Cleaning the Text**

# %%
_CLEAN_RE = re.compile(
    r"""
    ^\d+\s*            # leading number like "0  "
    |\[INST\].*?\[/INST\]  # full [INST] ... [/INST] block (non-greedy)
    |\[/?INST\]        # any leftover [INST] or [/INST]
    """,
    flags=re.DOTALL | re.MULTILINE | re.VERBOSE
)

# %%
def clean_text(text):
    text = _CLEAN_RE.sub("", text)
    text = re.sub(r"\s+", " ", text.replace("\n", " ")).strip()
    return text.strip()

# %%
df_clean = df["content"].apply(clean_text)
df_clean.head()
# Out:
# 0    I'm also buying more alts while anticipating t...
# 1    GM chat! ... 🧡 I want to start this day with s...
# 2    The biggest challenge in bringing TradFi and D...
# 3                                        $hunt is best
# 4                                                $Core
# Name: content, dtype: object

# %%
paragraph = ("".join(df_clean.dropna().astype(str)))
paragraph
# Out:
# 'I\'m also buying more alts while anticipating the launch of $XOR. ... With the $XOR IDO now live on @XorionChain until 31st August, it\'s the perfect time to secure your allocation.GM chat! ... 🧡 I want to start this day with short plan:@MavrykNetwork - working on another article about the project. ... be ready for alpha. ... @billions_ntwk - locking in the Billions discord to finally get my SUPER OG!@peaq - working on content and exploring Acurast. ... (alpha here - https://t.co/ypruXCvQkC)Let\'s make it fun, gang! 🧡 ... @avantisfi - gonna join Predator Arena to fight for 150k $OP@RialoHQ - building early mindshare and keep providing high quality content.The biggest challenge in bringing TradFi and DeFi together has always been the same: trust, compliance, and security.That’s exactly where Haven1 comes in. It’s not just another blockchain it’s a REKT resistant, compliant Layer 1 built to make DeFi safe, reliable, and open for everyone.Here’s why Haven1 is different 👇- Control & Transparency :— You stay in charge of your assets with self custody, while still enjoying open access to the network.- Compliance Without Compromise :— One time KYC unlocks a world where users can still interact pseudonymously, but institutions get the assurance they need.- Next-Level Security :— Haven1 is built to stop the common DeFi problems: MEV, front running, and smart contract exploits. There are also fraud proofs and dispute mechanisms for extra safety.- Real World Connection :— Native support for stablecoins like USDC/EURC, integration with payment rails like SWIFT/SEPA, and DEXs that meet compliance standards.- Liquidity That Works for All :— By bridging institutional capital into DeFi, Haven1 unlocks deep, reliable markets that benefit both everyday users and big players.- Governance That Balances :— DAO driven upgrades with a regulatory advisory council. Decentralization and compliance working together, not against each other.And with products like @hSwap_H1 for seamless trading and @hEarn_H1 for secure, compliant yields, @Haven1official is already building the tools for adoption at scale.This isn’t just another chain. It’s the missing bridge that can finally make global DeFi adoption a reality.The future isn’t TradFi vs DeFi.It’s TradFi through DeFi. #H1 #Haven1Up #RektResistance$hunt is best$CoreGme in its entire history has only ever moved sidewaysGmm AstaNew project on the Linea chain (project of Ethereum). ... You are still very early on this one. ... This is one that can still go x100/1000. ... Take a look at Foxy. ... Foxy is the biggest meme on this chain.Crypto was always meant to be multichain.One wallet. One contract.Real BTC, ETH, SOL no copies.Apps that just work.That’s what @zetablockchain delivers:▸ Decentralized validators▸ Built by real teams▸ Native cross-chain — no bridges, no wraps, no hacks.➘ Real projects are already live: Amana, Beam DEX, and more.This isn’t vaporware. It’s happening now.For devs, the flex is unreal:▸ Build once → deploy everywhere▸ Simpler logic → fewer bugs▸ Safer by design → no brittle workaroundsFor users:▸ Move assets without stress▸ Trust cross-chain apps▸ Finally feel crypto “click”➘ My favorite moment?Sending native BTC into an ETH vault with no bridge, no wait.It felt like magic.But it was Zeta’s universal layer.Before Zeta, every chain felt like an island.BTC here. ETH there. SOL in its corner.Powerful, but isolated.No bridges I trusted. No simple way to move.Then came the missing piece:Not another alt L1.The first Universal Blockchain.@zetablockchain connects them all, natively.And once you experience it, there’s no going back.Read more: https://t.co/t27gN22ank#ZetaChain #MultichainKaia Community Townhall- Kaia’s USDT Campaign and Stablecoin Hackathon KickoffXRP and SUIBullish on $LABS$ACH – Futures LONG SetupEntry: 0.0210Targets: 0.0220 / 0.0280 / 0.0320Stop-Loss: 0.02047 (≈ –50% margin risk, protecting half of the capital)ACH is forming a bullish Ascending Triangle on the 4H chart. Price ...

# %% [markdown]
# ### Sentences Frequency

# %%
sentences = re.split(r'(?<=[.!?])\s+', paragraph.strip())
print("Number of sentences =", len(sentences))
# Out:
# Number of sentences = 1715

# %% [markdown]
# **Using NLTK Sentence Tokenizer**

# %%
sentences = sent_tokenize(paragraph)
print("Number of sentences =", len(sentences))
# Out:
# Number of sentences = 1254

# %% [markdown]
# ## Word Frequency

# %%
words = paragraph.split()
print("Number of words =", len(words))
# Out:
# Number of words = 26895

# %%
words = word_tokenize(paragraph)
print("Number of words =", len(words))
# Out:
# Number of words = 34769

# %% [markdown]
# ### Tokenization

# %%
stop_words = set(stopwords.words('english'))
n = 50

# %%
def clean_token(token):
    token = re.sub(r"[^\w@$]", "", token)
    return token if token else None

# %%
tokens = paragraph.split()
#Clean the token so that @ and $ is allowed 
cleaned_tokens = [clean_token(t) for t in tokens]
#Remove empty tokens None, "" 
cleaned_tokens = [t for t in cleaned_tokens if t]

# %%
count=0
unique_tokens = set() 
print("ORIGINAL TOKENS WITH ID")
for i, token in enumerate(cleaned_tokens[:n]):
    word = token.lower()
    if word not in unique_tokens:
        print(i, ":", token)
        unique_tokens.add(word)
# Out:
# ORIGINAL TOKENS WITH ID
# 0 : Im
# 1 : also
# 2 : buying
# 3 : more
# 4 : alts
# 5 : while
# 6 : anticipating
# 7 : the
# 8 : launch
# 9 : of
# 10 : $XOR
# 11 : With
# 14 : IDO
# 15 : now
# 16 : live
# 17 : on
# 18 : @XorionChain
# 19 : until
# 20 : 31st
# 21 : August
# 22 : its
# 24 : perfect
# 25 : time
# 26 : to
# 27 : secure
# 28 : your
# 29 : allocationGM
# 30 : chat
# 31 : I
# 32 : want
# 34 : start
# 35 : this
# 36 : day
# 38 : short
# 39 : plan@MavrykNetwork
# 40 : working
# 42 : another
# 43 : article
# 44 : about
# 46 : project
# 47 : be
# 48 : ready
# 49 : for

# %%
## Assigning unique_tokens as set since a set cannot contain duplicate values

# %% [markdown]
# ### Stopword Filtering with Token Iteration

# %%
count = 0
for i, w in enumerate(cleaned_tokens[:n]):
    if w.lower() not in stop_words:
        print(i, ":", w)
        count += 1
        if count == 20:
            break
# Out:
# 0 : Im
# 1 : also
# 2 : buying
# 4 : alts
# 6 : anticipating
# 8 : launch
# 10 : $XOR
# 13 : $XOR
# 14 : IDO
# 16 : live
# 18 : @XorionChain
# 20 : 31st
# 21 : August
# 24 : perfect
# 25 : time
# 27 : secure
# 29 : allocationGM
# 30 : chat
# 32 : want
# 34 : start

# %% [markdown]
# ##### Observation: Stopword filtering removes commonly used words such as - more, while, the, of

# %%
# Do we remove the stop words from our cleaned token list?

# %% [markdown]
# ### Sentiment Analysis

# %%
buy = ["buy","buying","long","bullish","calls","moon","dip","breakout","undervalued","accumulate"]
sell = ["sell","selling","short","bearish","puts","dump","crash","overvalued","correction","exit"]

# %%
buy_count = 0 
sell_count = 0 
for w in cleaned_tokens:
    word = w.lower()
    if word in buy:
        buy_count +=1 
    elif word in sell:
        sell_count += 1

# Print results
print("Positive words count:", buy_count)
print("Negative words count:", sell_count)
# Out:
# Positive words count: 148
# Negative words count: 42

# %% [markdown]
# ### POS Tagging

# %%
# using pos_tag store each tag for a word in a tuple

# %%
pos_storage = nltk.pos_tag(cleaned_tokens)
pos_storage
# Out:
# [('Im', 'NNP'),
#  ('also', 'RB'),
#  ('buying', 'VBG'),
#  ('more', 'JJR'),
#  ('alts', 'NNS'),
#  ('while', 'IN'),
#  ('anticipating', 'VBG'),
#  ('the', 'DT'),
#  ('launch', 'NN'),
#  ('of', 'IN'),
#  ('$XOR', 'NN'),
#  ('With', 'IN'),
#  ('the', 'DT'),
#  ('$XOR', 'JJ'),
#  ('IDO', 'NNP'),
#  ('now', 'RB'),
#  ('live', 'VBP'),
#  ('on', 'IN'),
#  ('@XorionChain', 'NN'),
#  ('until', 'IN'),
#  ('31st', 'CD'),
#  ('August', 'NNP'),
#  ('its', 'PRP$'),
#  ('the', 'DT'),
#  ('perfect', 'JJ'),
#  ('time', 'NN'),
#  ('to', 'TO'),
#  ('secure', 'VB'),
#  ('your', 'PRP$'),
#  ('allocationGM', 'NN'),
#  ('chat', 'VBP'),
#  ('I', 'PRP'),
#  ('want', 'VBP'),
#  ('to', 'TO'),
#  ('start', 'VB'),
#  ('this', 'DT'),
#  ('day', 'NN'),
#  ('with', 'IN'),
#  ('short', 'JJ'),
#  ('plan@MavrykNetwork', 'NN'),
#  ('working', 'VBG'),
#  ('on', 'IN'),
#  ('another', 'DT'),
#  ('article', 'NN'),
#  ('about', 'IN'),
#  ('the', 'DT'),
#  ('project', 'NN'),
#  ('be', 'VB'),
#  ('ready', 'JJ'),
#  ('for', 'IN'),
#  ('alpha', 'JJ'),
#  ('@billions_ntwk', 'CD'),
#  ('locking', 'VBG'),
#  ('in', 'IN'),
#  ('the', 'DT'),
#  ('Billions', 'NNP'),
#  ('discord', 'NN'),
#  ('to', 'TO'),
#  ('finally', 'RB'),
#  ('get', 'VB'),
#  ('my', 'PRP$'),
#  ('SUPER', 'NNP'),
#  ('OG@peaq', 'NNP'),
#  ('working', 'VBG'),
#  ('on', 'IN'),
#  ('content', 'NN'),
#  ('and', 'CC'),
#  ('exploring', 'VBG'),
#  ('Acurast', 'NNP'),
#  ('alpha', 'NN'),
#  ('here', 'RB'),
#  ('httpstcoypruXCvQkCLets', 'NNS'),
#  ('make', 'VBP'),
#  ('it', 'PRP'),
#  ('fun', 'VBZ'),
#  ('gang', 'JJ'),
#  ('@avantisfi', 'NNP'),
#  ('gonna', 'NN'),
#  ('join', 'NN'),
#  ('Predator', 'NNP'),
#  ('Arena', 'NNP'),
#  ('to', 'TO'),
#  ('fight', 'VB'),
#  ('for', 'IN'),
#  ('150k', 'CD'),
#  ('$OP@RialoHQ', 'NNS'),
#  ('building', 'VBG'),
#  ('early', 'JJ'),
#  ('mindshare', 'NN'),
#  ('and', 'CC'),
#  ('keep', 'VB'),
#  ('providing', 'NN'),
#  ('high', 'JJ'),
#  ('quality', 'NN'),
#  ('contentThe', 'VBP'),
#  ('biggest', 'JJS'),
#  ('challenge', 'NN'),
#  ('in', 'IN'),
#  ('bringing', 'VBG'),
#  ('TradFi', 'NNP'),
#  ('and', 'CC'),
#  ('DeFi', 'NNP'),
#  ('together', 'RB'),
#  ('has', 'VBZ'),
#  ('always', 'RB'),
#  ('been', 'VBN'),
#  ('the', 'DT'),
#  ('same', 'JJ'),
#  ('trust', 'NN'),
#  ('compliance', 'NN'),
#  ('and', 'CC'),
#  ('securityThats', 'NNS'),
#  ('exactly', 'RB'),
#  ('where', 'WRB'),
#  ('Haven1', 'NNP'),
#  ('comes', 'VBZ'),
#  ('in', 'IN'),
#  ('Its', 'PRP$'),
#  ('not', 'RB'),
#  ('just', 'RB'),
#  ('another', 'DT'),
#  ('blockchain', 'NN'),
#  ('its', 'PRP$'),
#  ('a', 'DT'),
#  ('REKT', 'NNP'),
#  ('resistant', 'NN'),
#  ('compliant', 'NN'),
#  ('Layer', 'NNP'),
#  ('1', 'CD'),
#  ('built', 'NN'),
#  ('to', 'TO'),
#  ('make', 'VB'),
#  ('DeFi', 'NNP'),
#  ('safe', 'JJ'),
#  ('reliable', 'NN'),
#  ('and', 'CC'),
#  ('open', 'VB'),
#  ('for', 'IN'),
#  ('everyoneHeres', 'NNS'),
#  ('why', 'WRB'),
#  ('Haven1', 'NNP'),
#  ('is', 'VBZ'),
#  ('different', 'JJ'),
#  ('Control', 'NNP'),
#  ('Transparency', 'NNP'),
#  ('You', 'PRP'),
#  ('stay', 'VBP'),
#  ('in', 'IN'),
#  ('charge', 'NN'),
#  ('of', 'IN'),
#  ('your', 'PRP$'),
#  ('assets', 'NNS'),
#  ('with', 'IN'),
#  ('self', 'PRP'),
#  ('custody', 'NN'),
#  ('while', 'IN'),
#  ('still', 'RB'),
#  ('enjoying', 'VBG'),
#  ('open', 'JJ'),
#  ('access', 'NN'),
#  ('to', 'TO'),
#  ('the', 'DT'),
#  ('network', 'NN'),
#  ('Compliance', 'NN'),
#  ('Without', 'IN'),
#  ('Compromise', 'NNP'),
#  ('One', 'CD'),
#  ('time', 'NN'),
#  ('KYC', 'NNP'),
#  ('unlocks', 'VBZ'),
#  ('a', 'DT'),
#  ('world', 'NN'),
#  ('where', 'WRB'),
#  ('users', 'NNS'),
#  ('can', 'MD'),
#  ('still', 'RB'),
#  ('interact', 'VB'),
#  ('pseudonymously', 'RB'),
#  ('but', 'CC'),
#  ('institutions', 'NNS'),
#  ('get', 'VBP'),
#  ('the', 'DT'),
#  ('assurance', 'NN'),
#  ('they', 'PRP'),
#  ('need', 'VBP'),
#  ('NextLevel', 'NNP'),
#  ('Security', 'NNP'),
#  ('Haven1', 'NNP'),
#  ('is', 'VBZ'),
#  ('built', 'VBN'),
#  ('to', 'TO'),
#  ('stop', 'VB'),
#  ('the', 'DT'),
#  ('common', 'JJ'),
#  ('DeFi', 'NNP'),
#  ('problems', 'NNS'),
#  ('MEV', 'NNP'),
#  ('front', 'VBD'),
#  ('running', 'VBG'),
#  ('and', 'CC'),
#  ('smart', 'JJ'),
#  ('contract', 'NN'),
#  ('exploits', 'NNS'),
#  ('There', 'EX'),
#  ('are', 'VBP'),
#  ('also', 'RB'),
#  ('fraud', 'NN'),
#  ('proofs', 'NN'),
#  ('and', 'CC'),
#  ('dispute', 'NN'),
#  ('mechanisms', 'NNS'),
#  ('for', 'IN'),
#  ('extra', 'JJ'),
#  ('safety', 'NN'),
#  ('Real', 'NNP'),
#  ('World', 'NNP'),
#  ('Connection', 'NNP'),
#  ('Native', 'NNP'),
#  ('support', 'NN'),
#  ('for', 'IN'),
#  ('stablecoins', 'NNS'),
#  ('like', 'IN'),
#  ('USDCEURC', 'NNP'),
#  ('integration', 'NN'),
#  ('with', 'IN'),
#  ('payment', 'NN'),
#  ('rails', 'NNS'),
#  ('like', 'IN'),
#  ('SWIFTSEPA', 'NNP'),
#  ('and', 'CC'),
#  ('DEXs', 'NNP'),
#  ('that', 'IN'),
#  ('meet', 'NN'),
#  ('compliance', 'NN'),
#  ('standards', 'NNS'),
#  ('Liquidity', 'NNP'),
#  ('That', 'WDT'),
#  ('Works', 'VBZ'),
#  ('for', 'IN'),
#  ('All', 'DT'),
#  ('By', 'IN'),
#  ('bridging', 'VBG'),
#  ('institutional', 'JJ'),
#  ('capital', 'NN'),
#  ('into', 'IN'),
#  ('DeFi', 'NNP'),
#  ('Haven1', 'NNP'),
#  ('unlocks', 'VBZ'),
#  ('deep', 'JJ'),
#  ('reliable', 'JJ'),
#  ('markets', 'NNS'),
#  ('that', 'WDT'),
#  ('benefit', 'VBP'),
#  ('both', 'DT'),
#  ('everyday', 'JJ'),
#  ('users', 'NNS'),
#  ('and', 'CC'),
#  ('big', 'JJ'),
#  ('players', 'NNS'),
#  ('Governance', 'VBP'),
#  ('That', 'DT'),
#  ('Balances', 'NNP'),
#  ('DAO', 'NNP'),
#  ('driven', 'VBZ'),
#  ('upgrades', 'NNS'),
#  ('with', 'IN'),
#  ('a', 'DT'),
#  ('regulatory', 'JJ'),
#  ('advisory', 'JJ'),
#  ('council', 'NN'),
#  ('Decentralization', 'NNP'),
#  ('and', 'CC'),
#  ('compliance', 'NN'),
#  ('working', 'VBG'),
#  ('together', 'RB'),
#  ('not', 'RB'),
#  ('against', 'IN'),
#  ('each', 'DT'),
#  ('otherAnd', 'NN'),
#  ('with', 'IN'),
#  ('products', 'NNS'),
#  ('like', 'IN'),
#  ('@hSwap_H1', 'NN'),
#  ('for', 'IN'),
#  ('seamless', 'JJ'),
#  ('trading', 'NN'),
#  ('and', 'CC'),
#  ('@hEarn_H1', 'NNP'),
#  ('for', 'IN'),
#  ('secure', 'NN'),
#  ('compliant', 'JJ'),
#  ('yields', 'NNS'),
#  ('@Haven1official', 'JJ'),
#  ('is', 'VBZ'),
#  ('already', 'RB'),
#  ('building', 'VBG'),
#  ('the', 'DT'),
#  ('tools', 'NNS'),
#  ('for', 'IN'),
#  ('adoption', 'NN'),
#  ('at', 'IN'),
#  ('scaleThis', 'JJ'),
#  ('isnt', 'NN'),
#  ('just', 'RB'),
#  ('another', 'DT'),
#  ('chain', 'NN'),
#  ('Its', 'PRP$'),
#  ('the', 'DT'),
#  ('missing', 'VBG'),
#  ('bridge', 'NN'),
#  ('that', 'WDT'),
#  ('can', 'MD'),
#  ('finally', 'RB'),
#  ('make', 'VB'),
#  ('global', 'JJ'),
#  ('DeFi', 'NNP'),
#  ('adoption', 'NN'),
#  ('a', 'DT'),
#  ('realityThe', 'JJ'),
#  ('future', 'NN'),
#  ('isnt', 'NN'),
#  ('TradFi', 'NNP'),
#  ('vs', 'NN'),
#  ('DeFiIts', 'NNP'),
#  ('TradFi', 'NNP'),
#  ('through', 'IN'),
#  ('DeFi', 'NNP'),
#  ('H1', 'NNP'),
#  ('Haven1Up', 'NNP'),
#  ('RektResistance$hunt', 'NNP'),
#  ('is', 'VBZ'),
#  ('best$CoreGme', 'VBN'),
#  ('in', 'IN'),
#  ('its', 'PRP$'),
#  ('entire', 'JJ'),
#  ('history', 'NN'),
#  ('has', 'VBZ'),
#  ('only', 'RB'),
#  ('ever', 'RB'),
#  ('moved', 'VBN'),
#  ('sidewaysGmm', 'JJ'),
#  ('AstaNew', 'NNP'),
#  ('project', 'NN'),
#  ('on', 'IN'),
#  ('the', 'DT'),
#  ('Linea', 'NNP'),
#  ('chain', 'NN'),
#  ('project', 'NN'),
#  ('of', 'IN'),
#  ('Ethereum', 'NNP'),
#  ('You', 'PRP'),
#  ('are', 'VBP'),
#  ('still', 'RB'),
#  ('very', 'RB'),
#  ('early', 'RB'),
#  ('on', 'IN'),
#  ('this', 'DT'),
#  ('one', 'CD'),
#  ('This', 'DT'),
#  ('is', 'VBZ'),
#  ('one', 'CD'),
#  ('that', 'WDT'),
#  ('can', 'MD'),
#  ('still', 'RB'),
#  ('go', 'VB'),
#  ('x1001000', 'NNP'),
#  ('Take', 'NNP'),
#  ('a', 'DT'),
#  ('look', 'NN'),
#  ('at', 'IN'),
#  ('Foxy', 'NNP'),
#  ('Foxy', 'NNP'),
#  ('is', 'VBZ'),
#  ('the', 'DT'),
#  ('biggest', 'JJS'),
#  ('meme', 'NN'),
#  ('on', 'IN'),
#  ('this', 'DT'),
#  ('chainCrypto', 'NN'),
#  ('was', 'VBD'),
#  ('always', 'RB'),
#  ('meant', 'VBN'),
#  ('to', 'TO'),
#  ('be', 'VB'),
#  ('multichainOne', 'JJ'),
#  ('wallet', 'NN'),
#  ('One', 'CD'),
#  ('contractReal', 'NN'),
#  ('BTC', 'NNP'),
#  ('ETH', 'NNP'),
#  ('SOL', 'NNP'),
#  ('no', 'DT'),
#  ('copiesApps', 'NN'),
#  ('that', 'WDT'),
#  ('just', 'RB'),
#  ('workThats', 'VBZ'),
#  ('what', 'WP'),
#  ('@zetablockchain', 'NN'),
#  ('delivers', 'NNS'),
#  ('Decentralized', 'VBD'),
#  ('validators', 'NNS'),
#  ('Built', 'VBN'),
#  ('by', 'IN'),
#  ('real', 'JJ'),
#  ('teams', 'NNS'),
#  ('Native', 'VBP'),
#  ('crosschain', 'NN'),
#  ('no', 'DT'),
#  ('bridges', 'VBZ'),
#  ('no', 'DT'),
#  ('wraps', 'JJ'),
#  ('no', 'DT'),
#  ('hacks', 'NNS'),
#  ('Real', 'JJ'),
#  ('projects', 'NNS'),
#  ('are', 'VBP'),
#  ('already', 'RB'),
#  ('live', 'JJ'),
#  ('Amana', 'NNP'),
#  ('Beam', 'NNP'),
#  ('DEX', 'NNP'),
#  ('and', 'CC'),
#  ('moreThis', 'VB'),
#  ('isnt', 'NN'),
#  ('vaporware', 'NN'),
#  ('Its', 'PRP$'),
#  ('happening', 'VBG'),
#  ('nowFor', 'JJ'),
#  ('devs', 'NN'),
#  ('the', 'DT'),
#  ('flex', 'NN'),
#  ('is', 'VBZ'),
#  ('unreal', 'JJ'),
#  ('Build', 'NNP'),
#  ('once', 'RB'),
#  ('deploy', 'RB'),
#  ('everywhere', 'RB'),
#  ('Simpler', 'NNP'),
#  ('logic', 'NN'),
#  ('fewer', 'JJR'),
#  ('bugs', 'NNS'),
#  ('Safer', 'NNP'),
#  ('by', 'IN'),
#  ('design', 'NN'),
#  ('no', 'DT'),
#  ('brittle', 'NN'),
#  ('workaroundsFor', 'NN'),
#  ('users', 'NNS'),
#  ('Move', 'NNP'),
#  ('assets', 'NNS'),
#  ('without', 'IN'),
#  ('stress', 'NN'),
#  ('Trust', 'NNP'),
#  ('crosschain', 'NN'),
#  ('apps', 'NN'),
#  ('Finally', 'NNP'),
#  ('feel', 'VB'),
#  ('crypto', 'NN'),
#  ('click', 'NN'),
#  ('My', 'NNP'),
#  ('favorite', 'NN'),
#  ('momentSending', 'VBG'),
#  ('native', 'JJ'),
#  ('BTC', 'NNP'),
#  ('into', 'IN'),
#  ('an', 'DT'),
#  ('ETH', 'NNP'),
#  ('vault', 'NN'),
#  ('with', 'IN'),
#  ('no', 'DT'),
#  ('bridge', 'NN'),
#  ('no', 'RB'),
#  ('waitIt', 'JJ'),
#  ('felt', 'NNS'),
#  ('like', 'IN'),
#  ('magicBut', 'NN'),
#  ('it', 'PRP'),
#  ('was', 'VBD'),
#  ('Zetas', 'NNP'),
#  ('universal', 'JJ'),
#  ('layerBefore', 'RB'),
#  ('Zeta', 'NNP'),
#  ('every', 'DT'),
#  ('chain', 'NN'),
#  ('felt', 'VBD'),
#  ('like', 'IN'),
#  ('an', 'DT'),
#  ('islandBTC', 'NN'),
#  ('here', 'RB'),
#  ('ETH', 'NNP'),
#  ('there', 'EX'),
#  ('SOL', 'NNP'),
#  ('in', 'IN'),
#  ('its', 'PRP$'),
#  ('cornerPowerful', 'NN'),
#  ('but', 'CC'),
#  ('isolatedNo', 'JJ'),
#  ('bridges', 'NNS'),
#  ('I', 'PRP'),
#  ('trusted', 'VBD'),
#  ('No', 'DT'),
#  ('simple', 'JJ'),
#  ('way', 'NN'),
#  ('to', 'TO'),
#  ('moveThen', 'VB'),
#  ('came', 'VBD'),
#  ('the', 'DT'),
#  ('missing', 'VBG'),
#  ('pieceNot', 'NN'),
#  ('another', 'DT'),
#  ('alt', 'NN'),
#  ('L1The', 'NNP'),
#  ('first', 'RB'),
#  ('Universal', 'NNP'),
#  ('Blockchain@zetablockchain', 'NNP'),
#  ('connects', 'VBZ'),
#  ('them', 'PRP'),
#  ('all', 'DT'),
#  ('nativelyAnd', 'VBP'),
#  ('once', 'RB'),
#  ('you', 'PRP'),
#  ('experience', 'VBP'),
#  ('it', 'PRP'),
#  ('theres', 'VBZ'),
#  ('no', 'DT'),
#  ('going', 'VBG'),
#  ('backRead', 'RB'),
#  ('more', 'RBR'),
#  ('httpstcot27gN22ankZetaChain', 'JJ'),
#  ('MultichainKaia', 'NNP'),
#  ('Community', 'NNP'),
#  ('Townhall', 'NNP'),
#  ('Kaias', 'NNP'),
#  ('USDT', 'NNP'),
#  ('Campaign', 'NNP'),
#  ('and', 'CC'),
#  ('Stablecoin', 'NNP'),
#  ('Hackathon', 'NNP'),
#  ('KickoffXRP', 'NNP'),
#  ('and', 'CC'),
#  ('SUIBullish', 'NNP'),
#  ('on', 'IN'),
#  ('$LABS$ACH', 'NN'),
#  ('Futures', 'NNS'),
#  ('LONG', 'NNP'),
#  ('SetupEntry', 'NNP'),
#  ('00210Targets', 'VBZ'),
#  ('00220', 'CD'),
#  ('00280', 'CD'),
#  ('00320StopLoss', 'CD'),
#  ('002047', 'CD'),
#  ('50', 'CD'),
#  ('margin', 'NN'),
#  ('risk', 'NN'),
#  ('protecting', 'VBG'),
#  ('half', 'NN'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('capitalACH', 'NN'),
#  ('is', 'VBZ'),
#  ('forming', 'VBG'),
#  ('a', 'DT'),
#  ('bullish', 'JJ'),
#  ('Ascending', 'NNP'),
#  ('Triangle', 'NNP'),
#  ('on', 'IN'),
#  ('the', 'DT'),
#  ('4H', 'CD'),
#  ('chart', 'JJ'),
#  ('Price', 'NNP'),
#  ('is', 'VBZ'),
#  ('pressing', 'VBG'),
#  ('against', 'IN'),
#  ('resistance', 'NN'),
#  ('a', 'DT'),
#  ('breakout', 'NN'),
#  ('looks', 'VBZ'),
#  ('imminentDont', 'JJ'),
#  ('sleep', 'NN'),
#  ('on', 'IN'),
#  ('this', 'DT'),
#  ('one', 'CD'),
#  ('NexulonAI', 'NNP'),
#  ('is', 'VBZ'),
#  ('the', 'DT'),
#  ('future', 'JJ'),
#  ('$NEX', 'NNP'),
#  ('AI', 'NNP'),
#  ('nextgen', 'NN'),
#  ('crypto', 'NN'),
#  ('Crypto', 'NNP'),
#  ('Trends', 'NNP'),
#  ('Bitcoin', 'NNP'),
#  ('has', 'VBZ'),
#  ('stormed', 'VBN'),
#  ('back', 'RB'),
#  ('above', 'IN'),
#  ('$112000', 'NN'),
#  ('showing', 'VBG'),
#  ('serious', 'JJ'),
#  ('staying', 'VBG'),
#  ('power', 'NN'),
#  ('as', 'IN'),
#  ('Solana', 'NNP'),
#  ('quietly', 'RB'),
#  ('steals', 'VBZ'),
#  ('the', 'DT'),
#  ('spotlight', 'NN'),
#  ('with', 'IN'),
#  ('a', 'DT'),
#  ('4', 'CD'),
#  ('percent', 'NN'),
#  ('jump', 'NN'),
#  ('Whispers', 'NNS'),
#  ('from', 'IN'),
#  ('the', 'DT'),
#  ('Fed', 'NNP'),
#  ('and', 'CC'),
#  ('a', 'DT'),
#  ('brightening', 'NN'),
#  ('regulatory', 'JJ'),
#  ('outlook', 'NN'),
#  ('have', 'VBP'),
#  ('traders', 'NNS'),
#  ('buzzing', 'VBG'),
#  ('about', 'IN'),
#  ('a', 'DT'),
#  ('$150K', 'JJ'),
#  ('yearend', 'NN'),
#  ('target', 'NN'),
#  ('for', 'IN'),
#  ('BTC', 'NNP'),
#  ('Interestingly', 'NNP'),
#  ('early', 'JJ'),
#  ('Bitcoin', 'NNP'),
#  ('whales', 'NNS'),
#  ('are', 'VBP'),
#  ('rotating', 'VBG'),
#  ('into', 'IN'),
#  ('promising', 'JJ'),
#  ('altcoins', 'NNS'),
#  ('like', 'IN'),
#  ('Remittix', 'NNP'),
#  ('betting', 'VBG'),
#  ('big', 'JJ'),
#  ('on', 'IN'),
#  ('realworld', 'NN'),
#  ('use', 'NN'),
#  ('cases', 'NNS'),
#  ('This', 'DT'),
#  ('markets', 'NNS'),
#  ('heating', 'VBG'),
#  ('up', 'RP'),
#  ('fast', 'RB'),
#  ('stay', 'NN'),
#  ('focused', 'VBD'),
#  ('and', 'CC'),
#  ('ready', 'JJ'),
#  ('launchcoin', 'NN'),
#  ('$launchcoin', 'NN'),
#  ('Just', 'NNP'),
#  ('in', 'IN'),
#  ('146', 'CD'),
#  ('chads', 'NNS'),
#  ('have', 'VBP'),
#  ('aped', 'VBN'),
#  ('into', 'IN'),
#  ('LAUNCHCOIN', 'NNP'),
#  ('Current', 'NNP'),
#  ('market', 'NN'),
#  ('cap', 'NN'),
#  ('$584M', 'NN'),
#  ('with', 'IN'),
#  ('liquidity', 'NN'),
#  ('at', 'IN'),
#  ('255419', 'CD'),
#  ('SOL', 'NNP'),
#  ('$11M', 'VBD'),
#  ('0', 'CD'),
#  ('Total', 'NNP'),
#  ('holders', 'NNS'),
#  ('21743', 'CD'),
#  ('Check', 'NNP'),
#  ('the', 'DT'),
#  ('chart', 'NN'),
#  ('here', 'RB'),
#  ('httpstco29z5k4oMRN', 'VBZ'),
#  ('X', 'JJ'),
#  ('Talk', 'NNP'),
#  ('@Bitcoinhabebe', 'NNP'),
#  ('@StalkHQ', 'NNP'),
#  ('@Wolfy_XBT', 'NNP'),
#  ('@winiam4444', 'NNP'),
#  ('@MiyaHedge', 'NNP'),
#  ('@TheDonOfApes', 'NNP'),
#  ('@fomI', 'NNP'),
#  ('want', 'VBP'),
#  ('to', 'TO'),
#  ('appreciate', 'VB'),
#  ('and', 'CC'),
#  ('thank', 'VB'),
#  ('God', 'NNP'),
#  ('for', 'IN'),
#  ('using', 'VBG'),
#  ('@Trader_Natasha0', 'NN'),
#  ('to', 'TO'),
#  ('help', 'VB'),
#  ('me', 'PRP'),
#  ('Im', 'NNP'),
#  ('honestly', 'RB'),
#  ('saying', 'VBG'),
#  ('this', 'DT'),
#  ('to', 'TO'),
#  ('everyone', 'NN'),
#  ('I', 'PRP'),
#  ('invested', 'VBD'),
#  ('$1000', 'CD'),
#  ('USD', 'NNP'),
#  ('and', 'CC'),
#  ('today', 'NN'),
#  ('I', 'PRP'),
#  ('just', 'RB'),
#  ('received', 'VBD'),
#  ('$8500', 'JJ'),
#  ('USD', 'NNP'),
#  ('directly', 'RB'),
#  ('to', 'TO'),
#  ('my', 'PRP$'),
#  ('Bitcoin', 'NNP'),
#  ('walletThe', 'NN'),
#  ('Gorilla', 'NNP'),
#  ('logo', 'NN'),
#  ('on', 'IN'),
#  ('@bscscan', 'NNP'),
#  ('has', 'VBZ'),
#  ('just', 'RB'),
#  ('been', 'VBN'),
#  ('updated', 'VBN'),
#  ('This', 'DT'),
#  ('isnt', 'NN'),
#  ('just', 'RB'),
#  ('a', 'DT'),
#  ('new', 'JJ'),
#  ('look', 'NN'),
#  ('its', 'PRP$'),
#  ('a', 'DT'),
#  ('symbol', 'NN'),
#  ('of', 'IN'),
#  ('our', 'PRP$'),
#  ('evolution', 'NN'),
#  ('revolution', 'NN'),
#  ('growth', 'NN'),
#  ('and', 'CC'),
#  ('world', 'NN'),
#  ('class', 'NN'),
#  ('community', 'NN'),
#  ('power', 'NN'),
#  ('Original', 'NNP'),
#  ('G', 'NNP'),
#  ('will', 'MD'),
#  ('always', 'RB'),
#  ('belong', 'VB'),
#  ('to', 'TO'),
#  ('$GORILLA', 'VB'),
#  ('LFGorilla', 'NNP'),
#  ('Layer', 'NNP'),
#  ('httpsblockchainreporternetpepetooutpacedogecoininthenextmarketrallybutlayerbretthasbeentippedas2025s100xmemecoin',
#   'NN'),
#  ('$PEPE', 'NNP'),
#  ('$DOGEThe', 'NNP'),
#  ('question', 'NN'),
#  ('is', 'VBZ'),
#  ('where', 'WRB'),
#  ('does', 'VBZ'),
#  ('that', 'IN'),
#  ('liquidity', 'NN'),
#  ('go', 'VBP'),
#  ('Real', 'JJ'),
#  ('assets', 'NNS'),
#  ('digital', 'JJ'),
#  ('ownership', 'NN'),
#  ('global', 'JJ'),
#  ('markets', 'NNS'),
#  ('this', 'DT'),
#  ('is', 'VBZ'),
#  ('where', 'WRB'),
#  ('the', 'DT'),
#  ('next', 'JJ'),
#  ('leg', 'NN'),
#  ('starts', 'VBZ'),
#  ('RWAs', 'NNP'),
#  ('are', 'VBP'),
#  ('set', 'VBN'),
#  ('to', 'TO'),
#  ('lead', 'VB'),
#  ('and', 'CC'),
#  ('$Vax', 'VB'),
#  ('stands', 'NNS'),
#  ('at', 'IN'),
#  ('the', 'DT'),
#  ('centerHeres', 'NNS'),
#  ('why', 'WRB'),
#  ('Four', 'CD'),
#  ('Pillars', 'NNP'),
#  ('is', 'VBZ'),
#  ('a', 'DT'),
#  ('goto', 'NN'),
#  ('for', 'IN'),
#  ('crypto', 'JJ'),
#  ('trendsDont', 'NN'),
#  ('just', 'RB'),
#  ('chase', 'VB'),
#  ('pumps', 'NNS'),
#  ('hunt', 'NN'),
#  ('for', 'IN'),
#  ('undervalued', 'JJ'),
#  ('monsters$OCTA', 'NN'),
#  ('isnt', 'NN'),
#  ('hype', 'NN'),
#  ('its', 'PRP$'),
#  ('infrastructureReal', 'NN'),
#  ('tech', 'JJ'),
#  ('Real', 'NNP'),
#  ('products', 'NNS'),
#  ('Real', 'NNP'),
#  ('growth', 'NN'),
#  ('potentialDevs', 'VBP'),
#  ('shipping', 'VBG'),
#  ('Community', 'NNP'),
#  ('growingis', 'VBP'),
#  ('the', 'DT'),
#  ('next', 'JJ'),
#  ('big', 'JJ'),
#  ('wave', 'NN'),
#  ('bullrun', 'NN'),
#  ('altseasonETH', 'IN'),
#  ('trending', 'VBG'),
#  ('Grayscale', 'NNP'),
#  ('stacking', 'VBG'),
#  ('BTC', 'NNP'),
#  ('$GROK25B$', 'NNP'),
#  ('is', 'VBZ'),
#  ('next', 'JJ'),
#  ('Solana', 'NNP'),
#  ('SOL', 'NNP'),
#  ('just', 'RB'),
#  ('climbed', 'VBD'),
#  ('38', 'CD'),
#  ('to', 'TO'),
#  ('$21294', 'VB'),
#  ('smashing', 'VBG'),
#  ('through', 'IN'),
#  ('$201', 'JJ'),
#  ('resistance', 'NN'),
#  ('with', 'IN'),
#  ('bullish', 'JJ'),
#  ('RSI', 'NNP'),
#  ('and', 'CC'),
#  ('MACD', 'NNP'),
#  ('backing', 'VBG'),
#  ('the', 'DT'),
#  ('rallyDeFi', 'NN'),
#  ('TVL', 'NNP'),
#  ('hit', 'VBD'),
#  ('$117Bhighest', 'JJS'),
#  ('since', 'IN'),
#  ('Jan', 'NNP'),
#  ('2025signaling', 'CD'),
#  ('massive', 'JJ'),
#  ('ecosystem', 'NN'),
#  ('growth', 'NN'),
#  ('amid', 'IN'),
#  ('rising', 'VBG'),
#  ('adoptionAnalysts', 'NNS'),
#  ('are', 'VBP'),
#  ('buzzing', 'VBG'),
#  ('shortterm', 'JJ'),
#  ('targets', 'NNS'),
#  ('at', 'IN'),
#  ('$220$245', 'NN'),
#  ('with', 'IN'),
#  ('yearly', 'JJ'),
#  ('forecasts', 'NNS'),
#  ('averaging', 'VBG'),
#  ('$500If', 'NN'),
#  ('it', 'PRP'),
#  ('holds', 'VBZ'),
#  ('above', 'IN'),
#  ('$210', 'NN'),
#  ('we', 'PRP'),
#  ('could', 'MD'),
#  ('see', 'VB'),
#  ('even', 'RB'),
#  ('more', 'JJR'),
#  ('upsideBut', 'JJ'),
#  ('is', 'VBZ'),
#  ('it', 'PRP'),
#  ('too', 'RB'),
#  ('late', 'JJ'),
#  ('to', 'TO'),
#  ('buy', 'VB'),
#  ('SOLCheck', 'NNP'),
#  ('out', 'IN'),
#  ('our', 'PRP$'),
#  ('full', 'JJ'),
#  ('analysisPehle', 'NN'),
#  ('sirf', 'NN'),
#  ('BTC', 'NNP'),
#  ('tha', 'NN'),
#  ('ab', 'NN'),
#  ('34', 'CD'),
#  ('portfolio', 'NN'),
#  ('GROK25B', 'NNP'),
#  ('aur', 'VBZ'),
#  ('26k', 'CD'),
#  ('profit', 'NN'),
#  ('sab', 'NN'),
#  ('kuch', 'JJ'),
#  ('keh', 'NN'),
#  ('raha', 'NN'),
#  ('haiSolana', 'NN'),
#  ('will', 'MD'),
#  ('never', 'RB'),
#  ('fail', 'VB'),
#  ('baby', 'NN'),
#  ('$Kori', 'NNP'),
#  ('$ASCN', 'NNP'),
#  ('ASCOM', 'NNP'),
#  ('1H', 'CD'),
#  ('La', 'NNP'),
#  ('tendance', 'NN'),
#  ('haussière', 'NN'),
#  ('est', 'JJS'),
#  ('actuellement', 'NN'),
#  ('très', 'NN'),
#  ('forte', 'NN'),
#  ('sur', 'NN'),
#  ('ASCOM', 'NNP'),
#  ('N', 'NNP'),
#  ('Tant', 'NNP'),
#  ('que', 'NN'),
#  ('le', 'NN'),
#  ('cours', 'NNS'),
#  ('se', 'VBP'),
#  ('maintient', 'JJ'),
#  ('au', 'NN'),
#  ('dessus', 'NN'),
#  ('du', 'JJ'),
#  ('support', 'NN'),
#  ('à', 'NN'),
#  ('on', 'IN'),
#  ('pourrait', 'NN'),
#  ('chercher', 'NN'),
#  ('àWeb3', 'NN'),
#  ('did', 'VBD'),
#  ('Farmed', 'NNP'),
#  ('Mito', 'NNP'),
#  ('with', 'IN'),
#  ('ETH', 'NNP'),
#  ('for', 'IN'),
#  ('3000', 'CD'),
#  ('hours', 'NNS'),
#  ('only', 'RB'),
#  ('to', 'TO'),
#  ('get', 'VB'),
#  ('$003', 'JJ'),
#  ('in', 'IN'),
#  ('return', 'NN'),
#  ('Enough', 'NNP'),
#  ('is', 'VBZ'),
#  ('enough', 'JJ'),
#  ('XRPIve', 'NNP'),
#  ('been', 'VBN'),
#  ('in', 'IN'),
#  ('GBTCWe', 'NNP'),
#  ('have', 'VBP'),
#  ('been', 'VBN'),
#  ('above', 'IN'),
#  ('100k', 'CD'),
#  ('since', 'IN'),
#  ('the', 'DT'),
#  ('23', 'CD'),
#  ('of', 'IN'),
#  ('June', 'NNP'),
#  ('and', 'CC'),
#  ('have', 'VBP'),
#  ('never', 'RB'),
#  ('seen', 'VBN'),
#  ('it', 'PRP'),
#  ('again', 'RB'),
#  ('Is', 'VBZ'),
#  ('this', 'DT'),
#  ('the', 'DT'),
#  ('1k', 'CD'),
#  ('moment', 'NN'),
#  ('for', 'IN'),
#  ('bitcoinYes', 'NN'),
#  ('with', 'IN'),
#  ('the', 'DT'),
#  ('institutional', 'JJ'),
#  ('flow', 'JJ'),
#  ...]

# %%
unique_pos = {tag for word, tag in pos_storage}
pos_list = list(unique_pos)
print(pos_list)
# Out:
# ['PRP$', 'TO', 'NNS', 'UH', 'VBN', 'MD', 'VB', 'PRP', 'POS', 'VBD', 'VBG', 'RB', 'EX', 'WRB', 'RBS', 'WDT', 'RBR', 'JJ', 'CD', 'CC', 'WP', '$', 'VBZ', 'IN', 'RP', 'JJR', 'NNP', 'PDT', 'NNPS', 'VBP', 'JJS', 'NN', 'DT', 'FW']

# %%
pos_counts = Counter(tag for word, tag in pos_storage)
pos_counts
# Out:
# Counter({'NNP': 5106,
#          'NN': 4339,
#          'IN': 2345,
#          'JJ': 2032,
#          'DT': 1650,
#          'NNS': 1338,
#          'RB': 1021,
#          'VBZ': 942,
#          'CD': 888,
#          'VB': 829,
#          'VBP': 688,
#          'CC': 666,
#          'VBG': 661,
#          'PRP': 568,
#          'TO': 510,
#          'VBD': 429,
#          'VBN': 337,
#          'PRP$': 330,
#          'MD': 225,
#          'WRB': 136,
#          'JJR': 99,
#          'RP': 99,
#          'WDT': 83,
#          'WP': 69,
#          'FW': 62,
#          'JJS': 53,
#          'RBR': 45,
#          'EX': 22,
#          'NNPS': 22,
#          'PDT': 17,
#          '$': 13,
#          'RBS': 10,
#          'UH': 1,
#          'POS': 1})

# %% [markdown]
# **Filter by noun**

# %%
nouns = [word for word, tag in pos_storage if tag.startswith("NN")]
print(nouns)
# Out:
# ['Im', 'alts', 'launch', '$XOR', 'IDO', '@XorionChain', 'August', 'time', 'allocationGM', 'day', 'plan@MavrykNetwork', 'article', 'project', 'Billions', 'discord', 'SUPER', 'OG@peaq', 'content', 'Acurast', 'alpha', 'httpstcoypruXCvQkCLets', '@avantisfi', 'gonna', 'join', 'Predator', 'Arena', '$OP@RialoHQ', 'mindshare', 'providing', 'quality', 'challenge', 'TradFi', 'DeFi', 'trust', 'compliance', 'securityThats', 'Haven1', 'blockchain', 'REKT', 'resistant', 'compliant', 'Layer', 'built', 'DeFi', 'reliable', 'everyoneHeres', 'Haven1', 'Control', 'Transparency', 'charge', 'assets', 'custody', 'access', 'network', 'Compliance', 'Compromise', 'time', 'KYC', 'world', 'users', 'institutions', 'assurance', 'NextLevel', 'Security', 'Haven1', 'DeFi', 'problems', 'MEV', 'contract', 'exploits', 'fraud', 'proofs', 'dispute', 'mechanisms', 'safety', 'Real', 'World', 'Connection', 'Native', 'support', 'stablecoins', 'USDCEURC', 'integration', 'payment', 'rails', 'SWIFTSEPA', 'DEXs', 'meet', 'compliance', 'standards', 'Liquidity', 'capital', 'DeFi', 'Haven1', 'markets', 'users', 'players', 'Balances', 'DAO', 'upgrades', 'council', 'Decentralization', 'compliance', 'otherAnd', 'products', '@hSwap_H1', 'trading', '@hEarn_H1', 'secure', 'yields', 'tools', 'adoption', 'isnt', 'chain', 'bridge', 'DeFi', 'adoption', 'future', 'isnt', 'TradFi', 'vs', 'DeFiIts', 'TradFi', 'DeFi', 'H1', 'Haven1Up', 'RektResistance$hunt', 'history', 'AstaNew', 'project', 'Linea', 'chain', 'project', 'Ethereum', 'x1001000', 'Take', 'look', 'Foxy', 'Foxy', 'meme', 'chainCrypto', 'wallet', 'contractReal', 'BTC', 'ETH', 'SOL', 'copiesApps', '@zetablockchain', 'delivers', 'validators', 'teams', 'crosschain', 'hacks', 'projects', 'Amana', 'Beam', 'DEX', 'isnt', 'vaporware', 'devs', 'flex', 'Build', 'Simpler', 'logic', 'bugs', 'Safer', 'design', 'brittle', 'workaroundsFor', 'users', 'Move', 'assets', 'stress', 'Trust', 'crosschain', 'apps', 'Finally', 'crypto', 'click', 'My', 'favorite', 'BTC', 'ETH', 'vault', 'bridge', 'felt', 'magicBut', 'Zetas', 'Zeta', 'chain', 'islandBTC', 'ETH', 'SOL', 'cornerPowerful', 'bridges', 'way', 'pieceNot', 'alt', 'L1The', 'Universal', 'Blockchain@zetablockchain', 'MultichainKaia', 'Community', 'Townhall', 'Kaias', 'USDT', 'Campaign', 'Stablecoin', 'Hackathon', 'KickoffXRP', 'SUIBullish', '$LABS$ACH', 'Futures', 'LONG', 'SetupEntry', 'margin', 'risk', 'half', 'capitalACH', 'Ascending', 'Triangle', 'Price', 'resistance', 'breakout', 'sleep', 'NexulonAI', '$NEX', 'AI', 'nextgen', 'crypto', 'Crypto', 'Trends', 'Bitcoin', '$112000', 'power', 'Solana', 'spotlight', 'percent', 'jump', 'Whispers', 'Fed', 'brightening', 'outlook', 'traders', 'yearend', 'target', 'BTC', 'Interestingly', 'Bitcoin', 'whales', 'altcoins', 'Remittix', 'realworld', 'use', 'cases', 'markets', 'stay', 'launchcoin', '$launchcoin', 'Just', 'chads', 'LAUNCHCOIN', 'Current', 'market', 'cap', '$584M', 'liquidity', 'SOL', 'Total', 'holders', 'Check', 'chart', 'Talk', '@Bitcoinhabebe', '@StalkHQ', '@Wolfy_XBT', '@winiam4444', '@MiyaHedge', '@TheDonOfApes', '@fomI', 'God', '@Trader_Natasha0', 'Im', 'everyone', 'USD', 'today', 'USD', 'Bitcoin', 'walletThe', 'Gorilla', 'logo', '@bscscan', 'isnt', 'look', 'symbol', 'evolution', 'revolution', 'growth', 'world', 'class', 'community', 'power', 'Original', 'G', 'LFGorilla', 'Layer', 'httpsblockchainreporternetpepetooutpacedogecoininthenextmarketrallybutlayerbretthasbeentippedas2025s100xmemecoin', '$PEPE', '$DOGEThe', 'question', 'liquidity', 'assets', 'ownership', 'markets', 'leg', 'RWAs', 'stands', 'centerHeres', 'Pillars', 'goto', 'trendsDont', 'pumps', 'hunt', 'monsters$OCTA', 'isnt', 'hype', 'infrastructureReal', 'Real', 'products', 'Real', 'growth', 'Community', 'wave', 'bullrun', 'Grayscale', 'BTC', '$GROK25B$', 'Solana', 'SOL', 'resistance', 'RSI', 'MACD', 'rallyDeFi', 'TVL', 'Jan', 'ecosystem', 'growth', 'adoptionAnalysts', 'targets', '$220$245', 'forecasts', '$500If', '$210', 'SOLCheck', 'analysisPehle', 'sirf', 'BTC', 'tha', 'ab',  ...

# %% [markdown]
# **Filter by verb**

# %%
verbs = [word for word, tag in pos_storage if tag.startswith("VB")]
print(verbs)
# Out:
# ['buying', 'anticipating', 'live', 'secure', 'chat', 'want', 'start', 'working', 'be', 'locking', 'get', 'working', 'exploring', 'make', 'fun', 'fight', 'building', 'keep', 'contentThe', 'bringing', 'has', 'been', 'comes', 'make', 'open', 'is', 'stay', 'enjoying', 'unlocks', 'interact', 'get', 'need', 'is', 'built', 'stop', 'front', 'running', 'are', 'Works', 'bridging', 'unlocks', 'benefit', 'Governance', 'driven', 'working', 'is', 'building', 'missing', 'make', 'is', 'best$CoreGme', 'has', 'moved', 'are', 'is', 'go', 'is', 'was', 'meant', 'be', 'workThats', 'Decentralized', 'Built', 'Native', 'bridges', 'are', 'moreThis', 'happening', 'is', 'feel', 'momentSending', 'was', 'felt', 'trusted', 'moveThen', 'came', 'missing', 'connects', 'nativelyAnd', 'experience', 'theres', 'going', '00210Targets', 'protecting', 'is', 'forming', 'is', 'pressing', 'looks', 'is', 'has', 'stormed', 'showing', 'staying', 'steals', 'have', 'buzzing', 'are', 'rotating', 'betting', 'heating', 'focused', 'have', 'aped', '$11M', 'httpstco29z5k4oMRN', 'want', 'appreciate', 'thank', 'using', 'help', 'saying', 'invested', 'received', 'has', 'been', 'updated', 'belong', '$GORILLA', 'is', 'does', 'go', 'is', 'starts', 'are', 'set', 'lead', '$Vax', 'is', 'chase', 'potentialDevs', 'shipping', 'growingis', 'trending', 'stacking', 'is', 'climbed', '$21294', 'smashing', 'backing', 'hit', 'rising', 'are', 'buzzing', 'averaging', 'holds', 'see', 'is', 'buy', 'aur', 'fail', 'se', 'did', 'get', 'is', 'been', 'have', 'been', 'have', 'seen', 'Is', 'do', 'is', 'building', 'powering', 'getting', 'be', 'yearI', 'help', 'achieve', '世界大会スタートBYBIT', 'is', '$TROLLLets', 'earn', 'joining', 'timelimited', 'upcoming', 'put', 'ensure', 'Is', 'has', 'gained', 'restaking', 'compared', 'tokens', 'adds', 'hardwareaccelerated', 'push', 'furthertargeting', 'had', 'surging', 'correcting', 'is', 'is', 'depends', 'achieves', 'restaking', 'scaling', 'advantage', 'make', 'plays', 'scooped', 'supported', 'built', 'Check', 'makes', 'generate', 'is', 'giving', 'see', 'createThanks', 'got', 'saying', 'is', 'showing', 'be', 'bought', 'hedged', 'selling', 'be', 'see', 'playing', 'be', 'holding', 'thinking', 'selling', 'is', 'is', 'trying', 'create', 'create', 'snap', 'incoming', 'get', 'rolling', 'make', 'turn', 'goooo', 'is', 'reloading', 'is', 'has', 'been', 'holding', 'test', 'are', 'lining', 'is', 'built', 'outlast', '@PythNetwork', 'reaching', 'groundbreaking', 'bring', 'is', 'is', 'moving', 'scored', 'adds', 'sparking', 'have', 'Backed', 'staking', 'growing', 'is', 'gearing', '$welfCelebrating', 'hit', 'is', 'is', 'were', 'building', 'had', 'decentralized', 'resonated', 'excited', 'continue', 'find', 'connect', 'guide', 'is', 'start', 'generate', 'Check', 'get', 'consensus', 'hit', 'be', 'bringing', 'animated', 'pixelated', 'tuned', 'rails', 'warming', 'staking', 'pledge', 'refunds', 'baked', 'read', 'design', 'verify', 'siloed', 'tokenize', 'translating', 'steers', 'show', 'staking', 'allocatoryour', 'show', 'open', 'stack', 'itstake', 'watch', 'pumpfuncoins', 'signaling', 'fading', 'httpsblockchainreporternetwhaleactivitysuggestslackofconfidencefordogecoinandshibainuwhichmemecoinisbigmoneybacking', 'is', 'are', 'waiting', 'impreso', 'libres', 'gracias', 'podría', 'antes', 'printing', 'climbing', 'holding', 'shows', 'is', 'moving', 'preparing', 'staking', 'entering', '@Ton_blockchain', '$BTC', '$ETH', 'chat', 'are', 'calls', 'thoughNow', 'waiting', 'is', 'tops', 'do', 'convert', 'take', 'correct', 'had', 'cooled', 'interested', 'looks', 'make', 'Steve', 'watching', 'sol', 'sol', 'is', 'coming', 'are', 'be', 'eating', 'looks', 'get', 'forming', 'speak', 'is', 'undervalued', 'compared', 'outclasses', 'am', 'biased', 'is', 'dont', 'know', 'replicate', 'is', 'happening', 'experience', 'come', 'make', 'is', 'get', 'find', 'grow', 'win', 'made', 'exchagne', 'going', 'make', 'are', 'funded', 'hold', 'connect', 'focuses', 'enhancing', 'is', 'bringing', 'hop', 'got', 'paid', 'sharing', 'is', 'had', ...

# %% [markdown]
# **Group Words by POS Tag**

# %%
pos_grouped = defaultdict(list)
for word, tag in pos_storage:
    pos_grouped[tag].append(word)
pos_grouped
# Out:
# defaultdict(list,
#             {'NNP': ['Im',
#               'IDO',
#               'August',
#               'Billions',
#               'SUPER',
#               'OG@peaq',
#               'Acurast',
#               '@avantisfi',
#               'Predator',
#               'Arena',
#               'TradFi',
#               'DeFi',
#               'Haven1',
#               'REKT',
#               'Layer',
#               'DeFi',
#               'Haven1',
#               'Control',
#               'Transparency',
#               'Compromise',
#               'KYC',
#               'NextLevel',
#               'Security',
#               'Haven1',
#               'DeFi',
#               'MEV',
#               'Real',
#               'World',
#               'Connection',
#               'Native',
#               'USDCEURC',
#               'SWIFTSEPA',
#               'DEXs',
#               'Liquidity',
#               'DeFi',
#               'Haven1',
#               'Balances',
#               'DAO',
#               'Decentralization',
#               '@hEarn_H1',
#               'DeFi',
#               'TradFi',
#               'DeFiIts',
#               'TradFi',
#               'DeFi',
#               'H1',
#               'Haven1Up',
#               'RektResistance$hunt',
#               'AstaNew',
#               'Linea',
#               'Ethereum',
#               'x1001000',
#               'Take',
#               'Foxy',
#               'Foxy',
#               'BTC',
#               'ETH',
#               'SOL',
#               'Amana',
#               'Beam',
#               'DEX',
#               'Build',
#               'Simpler',
#               'Safer',
#               'Move',
#               'Trust',
#               'Finally',
#               'My',
#               'BTC',
#               'ETH',
#               'Zetas',
#               'Zeta',
#               'ETH',
#               'SOL',
#               'L1The',
#               'Universal',
#               'Blockchain@zetablockchain',
#               'MultichainKaia',
#               'Community',
#               'Townhall',
#               'Kaias',
#               'USDT',
#               'Campaign',
#               'Stablecoin',
#               'Hackathon',
#               'KickoffXRP',
#               'SUIBullish',
#               'LONG',
#               'SetupEntry',
#               'Ascending',
#               'Triangle',
#               'Price',
#               'NexulonAI',
#               '$NEX',
#               'AI',
#               'Crypto',
#               'Trends',
#               'Bitcoin',
#               'Solana',
#               'Fed',
#               'BTC',
#               'Interestingly',
#               'Bitcoin',
#               'Remittix',
#               'Just',
#               'LAUNCHCOIN',
#               'Current',
#               'SOL',
#               'Total',
#               'Check',
#               'Talk',
#               '@Bitcoinhabebe',
#               '@StalkHQ',
#               '@Wolfy_XBT',
#               '@winiam4444',
#               '@MiyaHedge',
#               '@TheDonOfApes',
#               '@fomI',
#               'God',
#               'Im',
#               'USD',
#               'USD',
#               'Bitcoin',
#               'Gorilla',
#               '@bscscan',
#               'Original',
#               'G',
#               'LFGorilla',
#               'Layer',
#               '$PEPE',
#               '$DOGEThe',
#               'RWAs',
#               'Pillars',
#               'Real',
#               'Real',
#               'Community',
#               'Grayscale',
#               'BTC',
#               '$GROK25B$',
#               'Solana',
#               'SOL',
#               'RSI',
#               'MACD',
#               'TVL',
#               'Jan',
#               'SOLCheck',
#               'BTC',
#               'GROK25B',
#               '$Kori',
#               '$ASCN',
#               'ASCOM',
#               'La',
#               'ASCOM',
#               'N',
#               'Tant',
#               'Farmed',
#               'Mito',
#               'ETH',
#               'Enough',
#               'XRPIve',
#               'GBTCWe',
#               'June',
#               'CT',
#               'AI',
#               'Bitcoin',
#               'Shes',
#               'WSOT',
#               '参加はコチラhttpstcoka6InCKNm9BYBIT',
#               '新規登録は約３分です招待コードはコチラKAIUNhttpstcoT1gSFwCoXs開運鬼龍BTC',
#               '$MNT',
#               'BitfinexEnjoy',
#               '@bitgetglobal',
#               'X',
#               '$SOL',
#               'X',
#               'BuiltonSolayer',
#               'Altcoin',
#               'Season',
#               'Solayers',
#               '$LAYER',
#               'Token',
#               'LAYER',
#               'Solanas',
#               'EigenLayer',
#               'Ethereum',
#               'LAYER',
#               'AVS',
#               'InfiniSVM',
#               'Solanas',
#               'TPS',
#               'Gbps',
#               'LAYER',
#               'ATH',
#               '$3',
#               '$060',
#               'So',
#               'LAYER',
#               'SOL',
#               'LAYER',
#               'Solayer',
#               'LAYERs',
#               'Solanaecosystem',
#               'OGs',
#               'ADA',
#               '$GROK25B',
#               '$AUTOS',
#               'Garage',
#               'BullishOnAUTOSWhether',
#               'NFTs',
#               'TRONEcoStar',
#               'AIpowered',
#               'NFT',
#               'NFT',
#               'Im',
#               'NFT',
#               'Pump',
#               'Je',
#               'Wil',
#               'Renzo',
#               'Aevo',
#               'Tia',
#               'OI',
#               'OI',
#               'MM',
#               'Crypto',
#               'Massive',
#               'Presale',
#               'Imo',
#               '@worldlibertyfi',
#               'Ohhh',
#               'Big',
#               'Lets',
#               'MC',
#               'Lets',
#               '$POLLY',
#               'Launch',
#               'Date',
#               'August',
#               'Time',
#               'UTC',
#               'Network',
#               '@base',
#               '@ClizaSystems',
#               'Website',
#               'SOON',
#               'Somewhere',
#               'Kenya',
#               'Bitcoin',
#               'ATM',
#               'Dont',
#               'NexulonAI',
#               '$NEX',
#               'AI',
#               'US',
#               'GDP',
#               'Injective',
#               'TURBO',
#               'XA59P',
#               'FLOKI',
#               'Toncoin',
#               'US',
#               'Users',
#               'Toncoin',
#               'Robinhood',
#               'Crypto',
#               'TON',
#               'Robinhood',
#               'Telegram',
#               '$708M',
#               'Tether',
#               'Institutional',
#               'TON',
#               'Altcoin',
#               'SeasonCheck',
#               '$core',
#               'Discord',
#               'BUIDL',
#               'Europe',
#               'AI',
#               'Were',
#               'European',
#               'Blockchain',
#               'Convention',
#               'Barcelona',
#               'Wed',
#               'Wallchain',
#               'AttentionFIf',
#               'Learn',
#               '@wallchain_xyzIn',
#               'So',
#               'XION',
#               'BTC',
#               'ETH',
#               'POLKADOT',
#               'POLYGON',
#               'Btc',
#               '$100kWhos',
#               'August',
#               'Ethereum',
#               'NFTs',
#               'ETHBuying',
#               '$1',
#               'BioXP',
#               'XP',
#               '$BIO',
#               'NFTs',
#               'Markets',
#               'Launchpad',
#               'Agents',
#               'IP',
#               'IPjust',
#               'BioDAOsgovernance',
#               'BioXP',
#               'BioDAOs',
#               'XRP',
#               'HBARMemeCoinSeason',
#               'Solana',
#               'SolanaMemeCoin',
#               '$tokabu',
#               '$troll',
#               '$pepe',
#               '$bome',
#               '$meme',
#               '$wojak',
#               '$eth',
#               '$btcWhales',
#               'DOGE',
#               'SHIB',
#               'Era713000$',
#               'USDT',
#               'Worth',
#               'OKX',
#               'Campaign',
#               'Jump',
#               'INProvide',
#               'Vault',
#               '$USDC',
#               'APY',
#               'Katana',
#               'NO',
#               'June',
#               'Price',
#               '$12$16',
#               'Trend',
#               'AI',
#               '$DPCORE',
#               '@DeepCore_io',
#               'StaFi',
#               'Build',
#               'AIpowered',
#               'LSaaS',
#               'Enable',
#               'Liquid',
#               'Staking',
#               'Vaults',
#               'LSVs',
#               'RWA',
#               'Spot',
#               'Expect',
#               'SubDAOsStaFi',
#               'FIS',
#               'HyperliquidTop',
#               'Aug',
#               'ORI',
#               '@Ton_blockchain',
#               'ORI',
#               '@Solana',
#               'ORI',
#               '@Bitcoin',
#               'ORI',
#               'ORI',
#               '@Uniswap',
#               'ORI',
#               '@Ethereum',
#               'ORI',
#               '@HyperliquidX',
#               'ORI',
#               '@Pumpdotfun',
#               'ORI',
#               '@0xPolygon',
#               'ORI',
#               'ORI',
#               'ORI',
#               '@KaitoAI',
#               'ORI',
#               '@Veloprotocol',
#               'ORI',
#               'OG',
#               '$SOL',
#               '$RAY',
#               'Crypto',
#               'AltcoinSeasonLets',
#               'AARK',
#               'Aark',
#               '$Wife',
#               '$1',
#               'Hedera',
#               'x',
#               'AI',
#               'Africa',
#               'Hackathon',
#               'Solana',
#               'Bitcoin',
#               'Right',
#               'Im',
#               'Shiba',
#               'Inu',
#               'Thank',
#               'Steve',
#               'Converted',
#               'XRP',
#               'Shiba',
#               'Inu',
#               'BeamThanks',
#               'SteveEvery',
#               'HINES',
#               'EL',
#               'GOBIERNO',
#               'DE',
#               'LOS',
#               'EEUU',
#               'COMPRARÁ',
#               'BITCOINEl',
#               'Casa',
#               'Blanca',
#               'Bo',
#               'Hines',
#               'EEUU',
#               'Bitcoinwould',
#               'MATH',
#               'NasdaqBottom',
#               'Kendu',
#               'Kendu',
#               'Kendu',
#               'Kendu',
#               'Stop',
#               'Kendu',
#               '$Slvr$Gain$Seraph$Yara',
#               '$Rlm',
#               '$PENGU',
#               'YFO',
#               'Ai',
#               'Sooon',
#               'ATH3200',
#               'K',
#               'Web',
#               'Farming',
#               'Dex',
#               'Live',
#               'Best',
#               'Defi',
#               'Micro',
#               'Market',
#               'WhalesGM',
#               'Drop',
#               'Solana',
#               'Were',
#               '@Godseer0',
#               'Drop',
#               'AI',
#               'Solana',
#               'Ready',
#               'X',
#               '@snoopfroggCa',
#               'ADSXPGwP3riuvqYtwqogCD4Rfn1a6NASqaSpThpsmoon',
#               'Ditch',
#               '$FROGG$JAGER',
#               'Lets',
#               'Go',
#               'Moonweeks',
#               'ID',
#               'ANY',
#               'ANYWAY',
#               'AT',
#               'ALL',
#               'ALL',
#               'BTCETHSOL',
#               'L2s',
#               'MantleBase',
#               'LINKPYTHMarch',
#               'BNB',
#               'LINK',
#               '$GROK25B$',
#               'SOL',
#               'BASE',
#               'kontra',
#               'çakıyor',
#               'ETH',
#               '$4759',
#               'TRON',
#               'Solidifies',
#               'Stablecoin',
#               'LeadershipThe',
#               'USDT',
#               'TRON',
#               'Beyond',
#               'Monthly',
#               'TRONs',
#               'TRON',
#               'Web3',
#               'TRONs',
#               'THE',
#               'US',
#               'OWNS',
#               'OVER',
#               'THE',
#               'TOTAL',
#               'BITCOIN',
#               'SUPPLY',
#               'BITCOIN',
#               'CRYPTO',
#               'USA',
#               'CryptoNews',
#               'CryptoMarket',
#               'Investinggood',
#               'Bitcoin',
#               'Asia',
#               'Conference',
#               'Hong',
#               'Kong',
#               'General',
#               'Admission',
#               'Im',
#               'Open',
#               'Will',
#               '$28',
#               'Nault',
#               'XNO',
#               'ETH',
#               'BTC',
#               'BTC',
#               'BTC',
#               'Blockchain',
#               'DigitalAssets',
#               'BTC',
#               'CryptoAdoptionClick',
#               'Binance',
#               'FuturesIDOLUSDT',
#               'All',
#               'Profit',
#               'Period',
#               'Hours',
#               'Minutes',
#               '$BTC',
#               '$ETH',
#               '$PEPE',
#               '$XRP',
#               '$AUDIO',
#               '$SUSHI',
#               '$GALA',
#               '$SOL',
#               '$TRUMP',
#               '$BABY',
#               '$AUDIO',
#               '$CRYPTO',
#               '$BNB',
#               '$USDT',
#               '$USD',
#               '$BULL',
#               '$TRX',
#               '$LTC',
#               '$LINKA',
#               '@monad',
#               'Strong',
#               'Solid',
#               'Community',
#               'Layer',
#               'EVM',
#               'Thursdays',
#               'Top',
#               'Altcoins',
#               '$CSIX2',
#               '$CRO3',
#               '$VRA4',
#               '$FURY5',
#               '$PUMP6',
#               '$ANYONE7',
#               '$XRP8',
#               '$TREE9',
#               '$TEL',
#               '$XPR11',
#               '$PROPS12',
#               '$NCDTRunner',
#               '$HYPE',
#               '$AI',
#               '$PLUME',
#               '$PHB',
#               '$KASAltseason2025',
#               'Altcoins',
#               '$DDYKuCoin',
#               'Important',
#               'NoticeCeluvPlay',
#               'CELB',
#               'Gets',
#               'KuCoin',
#               'World',
#               'PremiereDetail',
#               'CEO',
#               'MATT',
#               'COLE',
#               'PLANS',
#               '$700M',
#               'BITCOIN',
#               'BUY',
#               'AFTER',
#               'IPOChainlink',
#               'Reserve',
#               'How',
#               'Payment',
#               'Abstraction',
#               '$LINK',
#               'GrowthChainlinkReserve',
#               'ChainlinkMASSIVE',
#               'MOVE',
#               'INCOMING',
#               'ON',
#               'ORCAUSDT',
#               'SCREAMING',
#               'Were',
#               '$239',
#               'ENTRY',
#               'Locked',
#               '$239',
#               'STOP',
#               'LOSS',
#               '$2185',
#               'Minimal',
#               'TARGET',
#               'Eyes',
#               'ABSOLUTE',
#               'GOLD',
#               'Were',
#               '$250',
#               'NEXT',
#               'EXPLOSIVE',
#               'PLAY',
#               'Are',
#               'ORCA',
#               'ArkInvest',
#               'Top',
#               'Gainers',
#               'Binance',
#               'Alpha',
#               'HOLY',
#               'SHIT',
#               'Ive',
#               'SOL',
#               'HUNT',
#               'Tether',
#               'بدمج',
#               'دعم',
#               'USDT',
#               'في',
#               'نظام',
#               'البيتكوين',
#               'البيئي',
#               'مما',
#               'يسمح',
#               'بإجراء',
#               'تحويلات',
#               'محلية',
#               'عبر',
#               'شبكة',
#               'Lightning',
#               'Network',
#               'يضمن',
#               'هذا',
#               'الدمج',
#               'معاملات',
#               'أسرع',
#               'وأرخص',
#               'لـ',
#               'USDT',
#               'و',
#               'BTC',
#               'مما',
#               'يعزز',
#               'قابلية',
#               'التشغيل',
#               'البيني',
#               'للعملات',
#               'المشفرة',
#               'تهدف',
#               'هذه',
#               'الخطوة',
#               'المدعومة',
#               'من',
#               'Lightning',
#               'Labs',
#               'إلى',
#               'تسهيل',
#               'المدفوعات',
#               'الفورية',
#               'ومنخفضة',
#               'التكلفة',
#               'لكل',
#               'من',
#               'USDT',
#               'و',
#               'BTC',
#               'مما',
#               'يعزز',
#               'تجربة',
#               'المستخدم',
#               'ويحفز',
#               'على',
#               'اعتماد',
#               'العملات',
#               'المشفرة$Yukan',
#               '$Dtg',
#               '$Pht',
#               '$Ocicat',
#               '$TwdGm',
#               'TON$ASI',
#               'S1',
#               '$U',
#               'FDV',
#               'TGE',
#               'Union',
#               'Yappers',
#               'K4ito',
#               'Ill',
#               'U',
#               '$13650',
#               '$650M',
#               'FDVThese',
#               'Im',
#               'DePIN',
#               'Q3',
#               'Thank',
#               '$GOLDEN',
#               'CEX',
#               'ERC20',
#               'MEXCcomhttpsgoldeninutokenorgmexc',
#               'Bitruehttpsgoldeninutokenorgbitrue',
#               'UniswaphttpsappuniswaporgswapoutputCurrency0xd87996ff3d06858bfc20989aef50cc5fcd4d84ca',
#               'BEP20',
#               'PancakeSwaphttpspancakeswapfinanceswapoutputCurrency0x7d4984490c4c68f8ead9dddca6d04c514ef77324Please',
#               'Please',
#               'Market',
#               'Update',
#               'Rally',
#               '$CFX',
#               'DoubleBottom',
#               'Breakout',
#               'Trend',
#               'Far',
#               'CFX',
#               'Price',
#               'Resilience',
#               'Minor',
#               'Confluxs',
#               'BitplanetThe',
#               'Web3',
#               'ExecutorsTriggers',
#               'Guards',
#               'LEGO',
#               'Private',
#               'TEEs',
#               'MEV',
#               'Fast',
#               'Layer2',
#               'UX',
#               'DeFi',
#               'AI',
#               'Whether',
#               'DeFi',
#               'AI',
#               'TEN',
#               'ERC20',
#               'TAO',
#               'BREAKING',
#               'CFTC',
#               'US',
#               'Liquidity',
#               'Price',
#               'YOU',
#               'ONLY',
#               'BUY',
#               'AT',
#               'ATH',
#               'YOUR',
#               'PORT',
#               'WILL',
#               'ALWAYS',
#               'BE',
#               'AT',
#               'ATHsame',
#               'SEIHavent',
#               '$FLOW',
#               'New',
#               'ATH',
#               'VC',
#               'Flow',
#               'My',
#               '@multibank_io',
#               'BTC',
#               'GDP',
#               'Thats',
#               'IT',
#               'BTC',
#               'WEB3',
#               'CEX',
#               '$VOLTEthereum',
#               'ETFs',
#               '$18B',
#               'ETH',
#               '$ETHFull',
#               'Story',
#               'Below',
#               '$NVDA',
#               'Trade',
#               'Idea',
#               'Sell',
#               'August',
#               'Expiry',
#               'Strangle',
#               'Let',
#               'IV',
#               'No',
#               'MSTR',
#               'BTC',
#               'Pikamoon',
#               'PIKAMOON',
#               'SNEAK',
#               'PEEK',
#               'VFX',
#               'Solid',
#               '$HUNT',
#               'Do',
#               'DD',
#               'Succinct',
#               'Assuming',
#               'Could',
#               'Data',
#               'Availability',
#               '@soncoin_',
#               'Sol',
#               'Stay',
#               'Tap',
#               'Altseason',
#               'ETH',
#               'SOL',
#               'ETHs',
#               'SOLs',
#               'DOT',
#               'Top',
#               'Crypto',
#               'Gainers',
#               'Losers',
#               'Thu',
#               'Aug',
#               'Biggest',
#               'GainersPyth',
#               'Network',
#               '$CRO',
#               'Finance',
#               'Biggest',
#               'LosersKeeta',
#               '$KTA',
#               'Useless',
#               'Coin',
#               'WEMIX',
#               '@chainlink',
#               'Reserve',
#               '$1M',
#               '$DIA',
#               'DeFi',
#               'THIS',
#               'ONE',
#               'ALWASY',
#               'WILL',
#               'LETS',
#               'IT',
#               'Ai',
#               'Tool',
#               'Solana',
#               'Meteora',
#               'S2',
#               'Solanas',
#               'HawkFi',
#               'Season',
#               'Thats',
#               'DeFi',
#               'A',
#               'Thats',
#               'Fabiano',
#               'Game',
#               'Changer',
#               'Strategy',
#               'Solana',
#               '@FabianoSolana',
#               'Most',
#               '$BTC',
#               'HawkFi',
#               'BTC',
#               'SOL',
#               'BTC',
#               'SOL',
#               'HawkFi',
#               'Meteora',
#               'BlackRock',
#               'Ethereum',
#               'Big',
#               'BitgetOnchain',
#               'GOATed',
#               '$MARTINAs',
#               'Jake',
#               '$3',
#               'No',
#               '$250',
#               'Im',
#               'Anything',
#               'BREAKING',
#               'CryptoTwitter',
#               'CTCrypto',
#               '$trai',
#               'AI',
#               'BTC',
#               'Claim',
#               'Hemi',
#               'Genesis',
#               '$HEMI',
#               'Im',
#               'USDC',
#               'Dex',
#               'ETH',
#               'L1',
#               'Zypto',
#               'US',
#               'China',
#               'ADRs',
#               'HK',
#               'Massive',
#               'CNHrenminbi',
#               'US',
#               'Shockingly',
#               '$BABA',
#               '$JD',
#               '$NTES',
#               '$BZUN',
#               '$BIDU',
#               '$ATHM',
#               '$BILI',
#               '$TCOM',
#               '$EDU',
#               '$XPEV',
#               '$WB',
#               '$LI',
#               '$NIO',
#               '$ZH',
#               '$BEKE',
#               '$TME',
#               '$MPNGYI',
#               'Bitcoin',
#               'Next',
#               'Indiana',
#               'Stake',
#               'AUBRAI',
#               'Bio',
#               'App',
#               'Earn',
#               'BioXP',
#               'Use',
#               'BioXP',
#               'IPToken',
#               'BioAgent',
#               'AUBRAI',
#               'TG',
#               'CA',
#               'PREMIUM',
#               'SIGNAL',
#               'DM',
#               '$VVS',
#               '$TREE',
#               '$RLC',
#               '$NMR',
#               'LAUNCHCOIN',
#               'My',
#               '$PEPE',
#               'SmartChallenge',
#               'GuessTheChartFollowing',
#               '@bitgetglobal',
#               'RT',
#               'Tagging',
#               'USDT',
#               'Huge',
#               'LINK',
#               'Should',
#               'SBI',
#               'No',
#               'ScantoEarn',
#               '$trai',
#               'Letsexchange',
#               'SUNDOGPeople',
#               'Binance',
#               'Alpha',
#               'Binance',
#               'Alpha',
#               'Dont',
#               ...],
#              'RB': ['also',
#               'now',
#               'finally',
#               'here',
#               'together',
#               'always',
#               'exactly',
#               'not',
#               'just',
#               'still',
#               'still',
#               'pseudonymously',
#               'also',
#               'together',
#               'not',
#               'already',
#               'just',
#               'finally',
#               'only',
#               'ever',
#               'still',
#               'very',
#               'early',
#               'still',
#               'always',
#               'just',
#               'already',
#               'once',
#               'deploy',
#               'everywhere',
#               'no',
#               'layerBefore',
#               'here',
#               'first',
#               'once',
#               'backRead',
#               'back',
#               'quietly',
#               'fast',
#               'here',
#               'honestly',
#               'just',
#               'directly',
#               'just',
#               'just',
#               'always',
#               'just',
#               'just',
#               'even',
#               'too',
#               'never',
#               'only',
#               'never',
#               'again',
#               'quietly',
#               'highly',
#               'now',
#               'together',
#               'also',
#               'Probably',
#               'not',
#               'quickly',
#               'first',
#               'often',
#               'even',
#               'even',
#               'Still',
#               'firstmover',
#               'strategically',
#               'just',
#               'here',
#               'just',
#               'honestly',
#               'definitely',
#               'now',
#               'perfectly',
#               'really',
#               'well',
#               'probably',
#               'rather',
#               'actually',
#               'possibly',
#               'even',
#               'onchain',
#               'now',
#               'onchain',
#               'Slowly',
#               'then',
#               'once',
#               'just',
#               'now',
#               'fast',
#               'just',
#               'truly',
#               'just',
#               'really',
#               'basically',
#               'Well',
#               'ever',
#               'feel',
#               'upveBIO',
#               'nerfed',
#               'onchainIP',
#               'actually',
#               'still',
#               'steadily',
#               'not',
#               'back',
#               'immediately',
#               'roughly',
#               'now',
#               'very',
#               'soon',
#               'Still',
#               'soon',
#               'drastically',
#               'right',
#               'now',
#               'completely',
#               'genuinely',
#               'even',
#               'remotely',
#               'close',
#               'there',
#               'right',
#               'now',
#               'honestly',
#               'etc',
#               'accordingly',
#               'youre',
#               'just',
#               'ago',
#               'well',
#               'just',
#               'so',
#               'rarely',
#               'gounfortunately',
#               'nearly',
#               'already',
#               'far',
#               'only',
#               'once',
#               'officially',
#               'cheap',
#               'not',
#               'definitely',
#               'exactly',
#               'just',
#               'too',
#               '$GROK25B$',
#               'now',
#               'only',
#               'just',
#               'soon',
#               'historically',
#               'approximately',
#               'consistently',
#               'daily',
#               'increasingly',
#               'However',
#               'safely',
#               'efficiently',
#               'still',
#               'soon',
#               'out',
#               'just',
#               'truly',
#               'very',
#               'first',
#               'here',
#               'beautifully',
#               'Tightly',
#               'up',
#               'once',
#               'also',
#               'also',
#               'now',
#               'only',
#               'automatically',
#               'still',
#               'quietly',
#               'together',
#               'stay',
#               'enough',
#               'enough',
#               'just',
#               'about',
#               'even',
#               'trustlessly',
#               'offshore',
#               'Now',
#               'so',
#               'then',
#               'now',
#               'then',
#               'already',
#               'aside',
#               'not',
#               'quite',
#               'highly',
#               'still',
#               'really',
#               'practically',
#               'now',
#               'then',
#               'instead',
#               'just',
#               'even',
#               'hereWhat',
#               'together',
#               'now',
#               'very',
#               'then',
#               'publicly',
#               'there',
#               'still',
#               'not',
#               'just',
#               'quietly',
#               'so',
#               'here',
#               'even',
#               'extremely',
#               'just',
#               'now',
#               'S4y4nqQFxxFM5heBHLgUzeCj4cErDFxGHEFSwMcpumpOnly',
#               'now',
#               'also',
#               'just',
#               'So',
#               'really',
#               'aheadTime',
#               'again',
#               'not',
#               'just',
#               'just',
#               'not',
#               'just',
#               'instead',
#               'close',
#               'pretty',
#               'early',
#               'always',
#               'constantly',
#               'just',
#               'right',
#               'now',
#               'always',
#               'so',
#               'as',
#               'far',
#               'not',
#               'fairly',
#               'exactly',
#               'Not',
#               'just',
#               'forward',
#               'not',
#               'there',
#               'just',
#               'here',
#               'not',
#               'so',
#               'noise',
#               'up',
#               'back',
#               'youll',
#               'perfectly',
#               'basically',
#               'together',
#               'back',
#               'still',
#               'Now',
#               'just',
#               'just',
#               'always',
#               'still',
#               'first',
#               'well',
#               'not',
#               'not',
#               'automatically',
#               'effectively',
#               'simply',
#               'then',
#               'just',
#               'very',
#               'soon',
#               'somewhere',
#               'likely',
#               'now',
#               'forward',
#               'just',
#               'else',
#               'here',
#               'gotta',
#               'there',
#               'never',
#               'here',
#               'else',
#               'just',
#               'desperately',
#               'just',
#               'just',
#               'Then',
#               'enough',
#               'just',
#               'then',
#               'never',
#               'just',
#               'still',
#               'already',
#               'often',
#               'Not',
#               'blindly',
#               'not',
#               'strategically',
#               'Suddenly',
#               'not',
#               'So',
#               'not',
#               'never',
#               'straight',
#               'often',
#               'chainAbsolutely',
#               'definitely',
#               'yall',
#               'still',
#               'soon',
#               'potentially',
#               'now',
#               'not',
#               'now',
#               'definitely',
#               'even',
#               'also',
#               'not',
#               'clearly',
#               'directly',
#               'rely',
#               'indirectly',
#               'instead',
#               'consistently',
#               'back',
#               'back',
#               'just',
#               'Sometimes',
#               'fast',
#               'Then',
#               'not',
#               'too',
#               'not',
#               'exactly',
#               'seemingly',
#               'daily',
#               'now',
#               'basically',
#               'also',
#               'only',
#               'automatically',
#               'just',
#               'soon',
#               'really',
#               'often',
#               'entirely',
#               'elsewhere',
#               'well',
#               'instead',
#               'verifiably',
#               'fairly',
#               'only',
#               'just',
#               'dont',
#               'Not',
#               'still',
#               'daily',
#               'anywhere',
#               'here',
#               'back',
#               'fast',
#               'just',
#               'downside',
#               'already',
#               'onlyProvide',
#               'so',
#               'so',
#               'even',
#               'ever',
#               'soon',
#               'now',
#               'closely',
#               'here',
#               'ahead',
#               'everywhere',
#               'back',
#               'about',
#               'Currently',
#               'weekly',
#               'proportionally',
#               'Now',
#               'Usually',
#               'sometimes',
#               'Indeed',
#               'Currently',
#               'almost',
#               'daily',
#               'already',
#               'suddenly',
#               'just',
#               'seamlessly',
#               'Together',
#               'not',
#               'just',
#               'not',
#               'already',
#               'just',
#               'potentially',
#               'already',
#               'away',
#               'still',
#               'then',
#               'still',
#               'just',
#               'completely',
#               'already',
#               'once',
#               'not',
#               'just',
#               'then',
#               'instantly',
#               'currently',
#               'approximately',
#               'just',
#               'yet',
#               'now',
#               'never',
#               'back',
#               'ahead',
#               'also',
#               'not',
#               'almost',
#               'too',
#               'now',
#               'closely',
#               'lately',
#               'else',
#               'now',
#               'soon',
#               'definitely',
#               'there',
#               'back',
#               'eaten',
#               'even',
#               'already',
#               'here',
#               'not',
#               'well',
#               'still',
#               'not',
#               'first',
#               'close',
#               'finally',
#               'yet',
#               'here',
#               'ahead',
#               'now',
#               'effectively',
#               'only',
#               'discover',
#               'too',
#               'potentially',
#               'currently',
#               'significantly',
#               'bottomhistorically',
#               'just',
#               'not',
#               'just',
#               'not',
#               'back',
#               'again',
#               'far',
#               'then',
#               'just',
#               'not',
#               'later',
#               'not',
#               'so',
#               'hard',
#               'still',
#               'rather',
#               'upside',
#               'here',
#               'then',
#               'currently',
#               'just',
#               'even',
#               'so',
#               'only',
#               'now',
#               'probably',
#               'So',
#               'technically',
#               'now',
#               'thus',
#               'now',
#               'now',
#               'even',
#               'now',
#               'actually',
#               'already',
#               'always',
#               'too',
#               'often',
#               'along',
#               'maybe',
#               'Instead',
#               'rather',
#               'breakout',
#               'fast',
#               'still',
#               'probably',
#               'back',
#               'always',
#               'back',
#               'down',
#               'now',
#               'still',
#               'also',
#               'again',
#               'also',
#               'again',
#               'together',
#               'lately',
#               'first',
#               'just',
#               'not',
#               'then',
#               'so',
#               'right',
#               'now',
#               'just',
#               'away',
#               '$220',
#               'now',
#               'just',
#               'even',
#               'fast',
#               'Even',
#               'already',
#               'ahead',
#               'only',
#               'Very',
#               'soon',
#               'well',
#               'seriously',
#               'already',
#               'here',
#               'fast',
#               'almost',
#               'again',
#               'actually',
#               'right',
#               'now',
#               'perfectly',
#               'Here',
#               'Here',
#               'always',
#               'there',
#               'never',
#               'just',
#               'also',
#               'literally',
#               'honestly',
#               'also',
#               'accidentally',
#               'wrongly',
#               'slowly',
#               'approximately',
#               'not',
#               'also',
#               'there',
#               'just',
#               'together',
#               'lately',
#               'just',
#               'just',
#               'ever',
#               'always',
#               'often',
#               'away',
#               'never',
#               'never',
#               'anywhere',
#               'Here',
#               'already',
#               'here',
#               'mathWhat',
#               'almost',
#               'forever',
#               'so',
#               'so',
#               'far',
#               'definitely',
#               'not',
#               'very',
#               'Once',
#               'alone',
#               'Still',
#               'nowhere',
#               'just',
#               'just',
#               'down',
#               'just',
#               'now',
#               'not',
#               'Now',
#               'definitely',
#               'well',
#               'so',
#               'clearly',
#               'virtually',
#               'so',
#               'instantly',
#               'just',
#               'even',
#               'now',
#               'still',
#               'very',
#               'so',
#               'not',
#               'ahead',
#               'possibly',
#               'definitely',
#               'just',
#               'now',
#               'now',
#               'just',
#               'first',
#               'already',
#               'hard',
#               'just',
#               'actually',
#               'Also',
#               'not',
#               'here',
#               'here',
#               '$45k',
#               'else',
#               'usually',
#               'down',
#               'just',
#               'still',
#               'together',
#               'quite',
#               'here',
#               'Now',
#               'potentially',
#               'obviously',
#               'even',
#               'However',
#               'so',
#               'well',
#               'quite',
#               'just',
#               'publicly',
#               'strategically',
#               'Well',
#               'quite',
#               'even',
#               'not',
#               'so',
#               'definitely',
#               'ahead',
#               'too',
#               'often',
#               'upside',
#               'goRally',
#               'together',
#               'ever',
#               'fast',
#               'even',
#               'now',
#               'oneclick',
#               'quickly',
#               'still',
#               'instantly',
#               'strongly',
#               'firmly',
#               'as',
#               'long',
#               'securely',
#               'automatically',
#               'before',
#               'almost',
#               'basically',
#               'seriously',
#               'close',
#               'not',
#               'deliveredtrust',
#               'currently',
#               'just',
#               'once',
#               'actually',
#               'not',
#               'anywhere',
#               'later',
#               'already',
#               'just',
#               'Here',
#               'around',
#               'currently',
#               'always',
#               'together',
#               'Not',
#               'only',
#               'rapidly',
#               'not',
#               'there',
#               'literally',
#               'just',
#               'so',
#               'ahead',
#               'ago',
#               'much',
#               'even',
#               'not',
#               'just',
#               'unitedkingdom',
#               'nouvelle',
#               'really',
#               'honestly',
#               'around',
#               'absurdly',
#               'maybe',
#               'still',
#               'seamlessly',
#               'instead',
#               'casually',
#               'not',
#               'globally',
#               'especially',
#               'So',
#               'globally',
#               'actually',
#               'just',
#               'still',
#               'just',
#               'almost',
#               'there',
#               'not',
#               'just',
#               'soon',
#               'sure',
#               'much',
#               'just',
#               'itll',
#               'sustain',
#               'then',
#               'closely',
#               'responsibly',
#               'not',
#               'aggressively',
#               'very',
#               'now',
#               'only',
#               '$4850',
#               'back',
#               'here',
#               'already',
#               'pretty',
#               'use',
#               'north',
#               'shouldnt',
#               'still',
#               'Just',
#               'right',
#               'now$SEI',
#               'now',
#               'here',
#               'just',
#               'here',
#               'rapidly',
#               'safely',
#               'wisely',
#               'initially',
#               'back',
#               'never',
#               'solely',
#               'rather',
#               'genuinely',
#               'then',
#               'forward',
#               'especially',
#               'back',
#               'ahead',
#               'So',
#               'so',
#               '@MEXC_ArabicWere',
#               'explore',
#               'now',
#               'really',
#               'now',
#               'Instead',
#               'not',
#               'only',
#               'right',
#               'apps',
#               'then',
#               'finally',
#               'not',
#               'up',
#               'so',
#               'just',
#               'below',
#               'only',
#               'not',
#               'just',
#               'also',
#               'also',
#               'then',
#               'just',
#               'really',
#               'now',
#               'potentially',
#               'retracementsEspecially',
#               'recently',
#               'well',
#               'definitely',
#               'fast',
#               'only',
#               'just',
#               'Just',
#               'instead',
#               'well',
#               'break',
#               'already',
#               'then',
#               'only',
#               '850Only',
#               'only',
#               'really',
#               'just',
#               'down',
#               'there',
#               'then',
#               'just',
#               'only',
#               'back',
#               'ago',
#               'now',
#               'too',
#               'later',
#               'back',
#               'youll',
#               'perfectly',
#               'basically',
#               'together',
#               'still',
#               'down',
#               'nearly',
#               'alltime',
#               'back',
#               'basically',
#               'back',
#               'up',
#               'about',
#               'always',
#               'also',
#               'Now',
#               'appetite',
#               'still',
#               'only',
#               'just',
#               'relatively',
#               'well',
#               'absolutely',
#               'back',
#               'slightly',
#               'also',
#               'now',
#               'just',
#               'even',
#               'just',
#               'reportedly',
#               'now',
#               'contact',
#               'usually',
#               'quite',
#               'beautifully',
#               'only',
#               'ahead',
#               'now',
#               'here',
#               'just',
#               'early',
#               'earlier',
#               'just',
#               'back',
#               'everywhere',
#               'here',
#               'Now',
#               'continuously',
#               'not',
#               'only',
#               'also',
#               'soon',
#               'surprisingly',
#               'then',
#               'Not',
#               'before',
#               'now',
#               'just',
#               'now',
#               'clearly',
#               'not',
#               'only',
#               'also',
#               'down',
#               'recently',
#               'just',
#               'just',
#               'around',
#               'recently',
#               'now',
#               'currently',
#               'upward',
#               'However',
#               'upward',
#               'legDiscover',
#               'up',
#               'now',
#               'not',
#               'actually',
#               'maybe',
#               'here',
#               'again',
#               'now',
#               'even',
#               'usually',
#               'rarely',
#               'down',
#               'often',
#               'exactly',
#               'directly',
#               'safeguard',
#               'nearly',
#               'ahead',
#               'dont',
#               'just',
#               'just',
#               'up',
#               'now',
#               'officially',
#               'quicly',
#               'basically',
#               'only',
#               'not',
#               'often',
#               'really',
#               'actively',
#               'slowly',
#               'then',
#               'suddenly',
#               'actually',
#               'just',
#               'suddenly',
#               'even',
#               'first',
#               'never',
#               'always',
#               'double',
#               'automatically',
#               'soon',
#               'endExactly',
#               'also',
#               'just',
#               'not',
#               'just',
#               'really',
#               'never',
#               'now',
#               'later',
#               'now',
#               'again',
#               'still',
#               'too',
#               'yet',
#               'isnt',
#               'yet',
#               'so',
#               'else',
#               'usually',
#               'again',
#               'still',
#               'So',
#               'always',
#               'here',
#               'not',
#               'here',
#               'likely',
#               ...],
#              'VBG': ['buying',
#               'anticipating',
#               'working',
#               'locking',
#               'working',
#               'exploring',
#               'building',
#               'bringing',
#               'enjoying',
#               'running',
#               'bridging',
#               'working',
#               'building',
#               'missing',
#               'happening',
#               'momentSending',
#               'missing',
#               'going',
# ...
#               'APPhttpstco4JV1MoSoLOMissed',
#               'gamified',
#               'trusted',
#               'arent',
#               'لشراء',
#               'was',
#               'happened',
#               'built',
#               'bought',
#               'felt',
#               'satvB',
#               'height',
#               'saw',
#               'was',
#               'was',
#               'came',
#               'boomt',
#               'isnt',
#               'fuel',
#               'invested',
#               'left',
#               'launched',
#               '$PYTH',
#               '$USELESS',
#               '$WEMIX',
#               'quieran',
#               'seguidas',
#               'started',
#               'appeared',
#               'dropped',
#               'fade',
#               'launched',
#               'longed',
#               '$BURLTelcomMedia',
#               'laughed',
#               'came',
#               'was',
#               'was',
#               'thought',
#               'was',
#               'had',
#               'wed',
#               '$ZYSBREAKING',
#               'bought',
#               'bought',
#               'happened',
#               'got',
#               'shilled',
#               'coded',
#               'forgot',
#               'got',
#               '$PYTH',
#               'were',
#               'kept',
#               'put',
#               'alt',
#               'shit',
#               'küçük',
#               'kazanırken',
#               'gibi',
#               'closed',
#               'walked',
#               'knew',
#               'led',
#               'untaxed',
#               '$1425',
#               'scooped',
#               'orangorang',
#               'miliaran',
#               'awal',
#               'deposited',
#               'used',
#               'provided',
#               'assumed',
#               'was',
#               'lol',
#               'was',
#               'had',
#               'was',
#               'displayed',
#               'rugged',
#               'thrilled',
#               'laughed',
#               'was',
#               'said',
#               'did',
#               'filed',
#               'Ranked',
#               'Ranked',
#               'Ranked',
#               'Ranked',
#               'Burned',
#               '$116M',
#               'raised',
#               'happened',
#               'moved',
#               'got',
#               '$214M',
#               'Expected',
#               'verified',
#               'registered',
#               'mined',
#               'got',
#               'needed',
#               'learned',
#               'delivered',
#               'choke',
#               'came',
#               'addressed',
#               'was',
#               'updated',
#               'landed',
#               'spiked',
#               '기간',
#               'had',
#               'was',
#               'was',
#               'were',
#               'noted',
#               'tuned',
#               'got',
#               'opened',
#               'miss',
#               'missed',
#               'repost',
#               '$U',
#               'bought',
#               'felt',
#               'surged',
#               'httpstmede_OTC1My',
#               'was',
#               'was',
#               'Награда',
#               '$AURA',
#               'x',
#               'Posted',
#               'used',
#               'did',
#               'secured',
#               'were',
#               'beat',
#               'tried',
#               'scooped',
#               'used',
#               'fast',
#               'wanted',
#               'powered',
#               'set',
#               '상태라',
#               '이제',
#               'got',
#               'did',
#               'prepared',
#               'posted',
#               '$AERO',
#               '$WETH',
#               '$MORPHO',
#               'headed',
#               'invested',
#               'faced',
#               'began',
#               'predicted',
#               'Surprised',
#               'got',
#               'got',
#               'subscribed',
#               'subscribed',
#               'للمنطقة',
#               'تحت',
#               'الهدفالاول',
#               'تحت',
#               'thrilled',
#               'httpslibearacomfundbridgeandlibearalaunchregulatedtokenisedtreasuryfundonavalanchehttpslibearacomfundbridgeandlibearalaunchregulatedtokenisedtreasuryfundonavalancheCaught',
#               'httpsbitmartzendeskcomhcenusarticles40474275763355The',
#               'dropped',
#               'were',
#               'put',
#               'left',
#               'outCA',
#               'Core',
#               'left',
#               'knew',
#               'sol',
#               '$SOLJoin',
#               'Yeah',
#               'spawned',
#               'became',
#               'few$WCM',
#               'started',
#               'was',
#               'amp',
#               'Excited',
#               'hit',
#               'layer',
#               'forged',
#               'reached',
#               'happenedKey',
#               'decoded',
#               '$4600',
#               'outlined',
#               'surged',
#               'said',
#               'was',
#               'was',
#               'went',
#               'wed',
#               'decided',
#               'learned',
#               'began',
#               'made',
#               'got',
#               'hoarded',
#               'observed',
#               'launched',
#               'розмірі',
#               'проведення',
#               'acquired',
#               'got',
#               'had',
#               'was',
#               'was',
#               'rallied',
#               'renewed',
#               'prepared',
#               'bought',
#               'went',
#               'went',
#               'tripled',
#               'was',
#               'came',
#               'did',
#               'was',
#               'was',
#               '$TAO',
#               '$BNKR',
#               '@NEARProtocol',
#               '$RENDER',
#               '$GIZA',
#               '$VIRTUAL',
#               'Excited',
#               'did',
#               'received',
#               'was',
#               'crowdverified',
#               'did',
#               'trusted',
#               'gedachtIts'],
#              'EX': ['There',
#               'there',
#               'there',
#               '@0xSweepHere',
#               'there',
#               '$BKN',
#               'There',
#               'there',
#               'there',
#               'there',
#               'there',
#               'there',
#               'there',
#               'EndsHere',
#               'there',
#               'There',
#               'There',
#               'there',
#               'opportunitiesHere',
#               'there',
#               'there',
#               'There'],
#              'WDT': ['That',
#               'that',
#               'that',
#               'that',
#               'that',
#               'that',
#               'that',
#               'that',
#               'that',
#               'that',
#               'that',
#               'which',
#               'that',
#               'which',
#               'that',
#               'which',
#               'that',
#               'that',
#               'that',
#               'that',
#               'that',
#               'that',
#               'that',
#               'that',
#               'that',
#               'that',
#               'which',
#               'that',
#               'that',
#               'that',
#               'that',
#               'that',
#               'that',
#               'that',
#               'that',
#               'that',
#               'that',
#               'which',
#               'that',
#               'which',
#               'that',
#               'which',
#               'that',
#               'which',
#               'which',
#               'that',
#               'that',
#               'which',
#               'which',
#               'that',
#               'that',
#               'that',
#               'which',
#               'which',
#               'questionWhat',
#               'that',
#               'that',
#               'that',
#               'which',
#               'that',
#               'which',
#               'that',
#               'that',
#               'doesnt',
#               'which',
#               'which',
#               'which',
#               'that',
#               'that',
#               'that',
#               'that',
#               'which',
#               'that',
#               'which',
#               'that',
#               'that',
#               'which',
#               'that',
#               'that',
#               'that',
#               'that',
#               'which',
#               'which'],
#              'WP': ['what',
#               'who',
#               'what',
#               'what',
#               'energyWhat',
#               'What',
#               'what',
#               'who',
#               '@cookiedotfunWhat',
#               'what',
#               'who',
#               'what',
#               'what',
#               'what',
#               'What',
#               'what',
#               'who',
#               'etcWhat',
#               'what',
#               'What',
#               'what',
#               'What',
#               'who',
#               'what',
#               'what',
#               'What',
#               'who',
#               'what',
#               'what',
#               'what',
#               'what',
#               '@ton_blockchainWhat',
#               'what',
#               'who',
#               'What',
#               'What',
#               'who',
#               'What',
#               'what',
#               'what',
#               'who',
#               'who',
#               'who',
#               'who',
#               'what',
#               'who',
#               'what',
#               'what',
#               'what',
#               'what',
#               'what',
#               'who',
#               'What',
#               'what',
#               'what',
#               'what',
#               'what',
#               '$BKN',
#               'what',
#               'who',
#               'who',
#               'who',
#               'what',
#               'What',
#               'what',
#               'what',
#               'who',
#               'What',
#               'What'],
#              'RBR': ['more',
#               'more',
#               'more',
#               'less',
#               'better',
#               'more',
#               'more',
#               'more',
#               'more',
#               'better',
#               'more',
#               'more',
#               'more',
#               'more',
#               'more',
#               'more',
#               'faster',
#               'more',
#               'harder',
#               'higherReal',
#               'MORE',
#               'less',
#               'etcDont',
#               'more',
#               'more',
#               'faster',
#               'more',
#               'further',
#               'more',
#               'more',
#               'earlier',
#               'more',
#               'more',
#               'lower',
#               'faster',
#               'more',
#               'more',
#               'later',
#               'more',
#               'more',
#               'more',
#               'More',
#               'more',
#               'more',
#               'faster'],
#              'RP': ['up',
#               'out',
#               'out',
#               'up',
#               'up',
#               'out',
#               'up',
#               'up',
#               'up',
#               'off',
#               'down',
#               'out',
#               'out',
#               'out',
#               'out',
#               'up',
#               'down',
#               'up',
#               'up',
#               'down',
#               'out',
#               'up',
#               'out',
#               'out',
#               'down',
#               'out',
#               'over',
#               'out',
#               'over',
#               'up',
#               'out',
#               'out',
#               'up',
#               'up',
#               'thats',
#               'up',
#               'up',
#               'out',
#               'up',
#               'apps',
#               'up',
#               'down',
#               'up',
#               'up',
#               'out',
#               'up',
#               'out',
#               'off',
#               'back',
#               'out',
#               'up',
#               'out',
#               'up',
#               'out',
#               'up',
#               'up',
#               'up',
#               'up',
#               'up',
#               'up',
#               'down',
#               'out',
#               'up',
#               'out',
#               'out',
#               'up',
#               'up',
#               'up',
#               'off',
#               'out',
#               'out',
#               'up',
#               'out',
#               'up',
#               'out',
#               'up',
#               'out',
#               'up',
#               'up',
#               'up',
#               'up',
#               'out',
#               'up',
#               'out',
#               'out',
#               'up',
#               'up',
#               'up',
#               'up',
#               'out',
#               'up',
#               'up',
#               'up',
#               'up',
#               'out',
#               'up',
#               'out',
#               'up',
#               'up'],
#              'UH': ['YES'],
#              'RBS': ['most',
#               'most',
#               'most',
#               'most',
#               'most',
#               'most',
#               'most',
#               'most',
#               'most',
#               'best'],
#              'FW': ['voor',
#               'de',
#               'update',
#               'de',
#               'andere',
#               'en',
#               'en',
#               'mis',
#               'de',
#               'en',
#               'la',
#               'red',
#               'de',
#               '@katana',
#               'del',
#               'la',
#               'estimación',
#               'de',
#               'que',
#               'el',
#               'token',
#               'de',
#               'realizar',
#               'de',
#               'criptomonedas',
#               'de',
#               'la',
#               '$1000',
#               'portafolio',
#               'en',
#               '$lightspeed',
#               'vs',
#               'everDefi',
#               'de',
#               'en',
#               'el',
#               'par',
#               'de',
#               '$SOL',
#               'de',
#               'el',
#               'de',
#               'portafolio',
#               'en',
#               'en',
#               'en',
#               'bikin',
#               'makin',
#               'kredibel',
#               'kayak',
#               'sKAITO',
#               'la',
#               'próxima',
#               'corrida',
#               'de',
#               'de',
#               'explotar',
#               'en',
#               'ni',
#               'se',
#               'pregunta',
#               'kommt'],
#              'NNPS': ['Whats',
#               'Assets',
#               'Whats',
#               'Billions',
#               'Products',
#               'Products',
#               'Whats',
#               'Robotics',
#               'Indicators',
#               'States',
#               'Investors',
#               'Savings',
#               'Futures',
#               'Investors',
#               'Traders',
#               'TokensLets',
#               'Assets',
#               'users',
#               'Thats',
#               'Projects',
#               'Projects',
#               'Lets'],
#              'PDT': ['all',
#               '$175B',
#               'till',
#               '$ALGOIs',
#               '$FUUU',
#               'such',
#               'all',
#               'All',
#               '$AVAXIts',
#               '$001',
#               'all',
#               'all',
#               'apps',
#               'all',
#               '$FUUU',
#               '$HUNT',
#               'all'],
#              '$': ['defi',
#               '$',
#               '$',
#               '$SOL',
#               '$BINUMin',
#               '$',
#               'üzerinde',
#               'latencyWith',
#               '対照的にETH現物ETFは',
#               '$sisa',
#               '$GROK25B',
#               'токена',
#               '$NEAR'],
#              'POS': ['vibes']})

# %% [markdown]
# **Converting to data frame**

# %%
df_pos = pd.DataFrame(pos_storage, columns=["word", "pos"])
df_pos
# Out:
#           word  pos
# 0           Im  NNP
# 1         also   RB
# 2       buying  VBG
# 3         more  JJR
# 4         alts  NNS
# ...        ...  ...
# 25631      pop  VBP
# 25632     with   IN
# 25633  gifting   NN
# 25634      and   CC
# 25635  tipping   NN
#
# [25636 rows x 2 columns]

# %%
filtered = [ (w, t) for w, t in pos_storage if t.startswith(("NN", "VB")) ]
filtered
# Out:
# [('Im', 'NNP'),
#  ('buying', 'VBG'),
#  ('alts', 'NNS'),
#  ('anticipating', 'VBG'),
#  ('launch', 'NN'),
#  ('$XOR', 'NN'),
#  ('IDO', 'NNP'),
#  ('live', 'VBP'),
#  ('@XorionChain', 'NN'),
#  ('August', 'NNP'),
#  ('time', 'NN'),
#  ('secure', 'VB'),
#  ('allocationGM', 'NN'),
#  ('chat', 'VBP'),
#  ('want', 'VBP'),
#  ('start', 'VB'),
#  ('day', 'NN'),
#  ('plan@MavrykNetwork', 'NN'),
#  ('working', 'VBG'),
#  ('article', 'NN'),
#  ('project', 'NN'),
#  ('be', 'VB'),
#  ('locking', 'VBG'),
#  ('Billions', 'NNP'),
#  ('discord', 'NN'),
#  ('get', 'VB'),
#  ('SUPER', 'NNP'),
#  ('OG@peaq', 'NNP'),
#  ('working', 'VBG'),
#  ('content', 'NN'),
#  ('exploring', 'VBG'),
#  ('Acurast', 'NNP'),
#  ('alpha', 'NN'),
#  ('httpstcoypruXCvQkCLets', 'NNS'),
#  ('make', 'VBP'),
#  ('fun', 'VBZ'),
#  ('@avantisfi', 'NNP'),
#  ('gonna', 'NN'),
#  ('join', 'NN'),
#  ('Predator', 'NNP'),
#  ('Arena', 'NNP'),
#  ('fight', 'VB'),
#  ('$OP@RialoHQ', 'NNS'),
#  ('building', 'VBG'),
#  ('mindshare', 'NN'),
#  ('keep', 'VB'),
#  ('providing', 'NN'),
#  ('quality', 'NN'),
#  ('contentThe', 'VBP'),
#  ('challenge', 'NN'),
#  ('bringing', 'VBG'),
#  ('TradFi', 'NNP'),
#  ('DeFi', 'NNP'),
#  ('has', 'VBZ'),
#  ('been', 'VBN'),
#  ('trust', 'NN'),
#  ('compliance', 'NN'),
#  ('securityThats', 'NNS'),
#  ('Haven1', 'NNP'),
#  ('comes', 'VBZ'),
#  ('blockchain', 'NN'),
#  ('REKT', 'NNP'),
#  ('resistant', 'NN'),
#  ('compliant', 'NN'),
#  ('Layer', 'NNP'),
#  ('built', 'NN'),
#  ('make', 'VB'),
#  ('DeFi', 'NNP'),
#  ('reliable', 'NN'),
#  ('open', 'VB'),
#  ('everyoneHeres', 'NNS'),
#  ('Haven1', 'NNP'),
#  ('is', 'VBZ'),
#  ('Control', 'NNP'),
#  ('Transparency', 'NNP'),
#  ('stay', 'VBP'),
#  ('charge', 'NN'),
#  ('assets', 'NNS'),
#  ('custody', 'NN'),
#  ('enjoying', 'VBG'),
#  ('access', 'NN'),
#  ('network', 'NN'),
#  ('Compliance', 'NN'),
#  ('Compromise', 'NNP'),
#  ('time', 'NN'),
#  ('KYC', 'NNP'),
#  ('unlocks', 'VBZ'),
#  ('world', 'NN'),
#  ('users', 'NNS'),
#  ('interact', 'VB'),
#  ('institutions', 'NNS'),
#  ('get', 'VBP'),
#  ('assurance', 'NN'),
#  ('need', 'VBP'),
#  ('NextLevel', 'NNP'),
#  ('Security', 'NNP'),
#  ('Haven1', 'NNP'),
#  ('is', 'VBZ'),
#  ('built', 'VBN'),
#  ('stop', 'VB'),
#  ('DeFi', 'NNP'),
#  ('problems', 'NNS'),
#  ('MEV', 'NNP'),
#  ('front', 'VBD'),
#  ('running', 'VBG'),
#  ('contract', 'NN'),
#  ('exploits', 'NNS'),
#  ('are', 'VBP'),
#  ('fraud', 'NN'),
#  ('proofs', 'NN'),
#  ('dispute', 'NN'),
#  ('mechanisms', 'NNS'),
#  ('safety', 'NN'),
#  ('Real', 'NNP'),
#  ('World', 'NNP'),
#  ('Connection', 'NNP'),
#  ('Native', 'NNP'),
#  ('support', 'NN'),
#  ('stablecoins', 'NNS'),
#  ('USDCEURC', 'NNP'),
#  ('integration', 'NN'),
#  ('payment', 'NN'),
#  ('rails', 'NNS'),
#  ('SWIFTSEPA', 'NNP'),
#  ('DEXs', 'NNP'),
#  ('meet', 'NN'),
#  ('compliance', 'NN'),
#  ('standards', 'NNS'),
#  ('Liquidity', 'NNP'),
#  ('Works', 'VBZ'),
#  ('bridging', 'VBG'),
#  ('capital', 'NN'),
#  ('DeFi', 'NNP'),
#  ('Haven1', 'NNP'),
#  ('unlocks', 'VBZ'),
#  ('markets', 'NNS'),
#  ('benefit', 'VBP'),
#  ('users', 'NNS'),
#  ('players', 'NNS'),
#  ('Governance', 'VBP'),
#  ('Balances', 'NNP'),
#  ('DAO', 'NNP'),
#  ('driven', 'VBZ'),
#  ('upgrades', 'NNS'),
#  ('council', 'NN'),
#  ('Decentralization', 'NNP'),
#  ('compliance', 'NN'),
#  ('working', 'VBG'),
#  ('otherAnd', 'NN'),
#  ('products', 'NNS'),
#  ('@hSwap_H1', 'NN'),
#  ('trading', 'NN'),
#  ('@hEarn_H1', 'NNP'),
#  ('secure', 'NN'),
#  ('yields', 'NNS'),
#  ('is', 'VBZ'),
#  ('building', 'VBG'),
#  ('tools', 'NNS'),
#  ('adoption', 'NN'),
#  ('isnt', 'NN'),
#  ('chain', 'NN'),
#  ('missing', 'VBG'),
#  ('bridge', 'NN'),
#  ('make', 'VB'),
#  ('DeFi', 'NNP'),
#  ('adoption', 'NN'),
#  ('future', 'NN'),
#  ('isnt', 'NN'),
#  ('TradFi', 'NNP'),
#  ('vs', 'NN'),
#  ('DeFiIts', 'NNP'),
#  ('TradFi', 'NNP'),
#  ('DeFi', 'NNP'),
#  ('H1', 'NNP'),
#  ('Haven1Up', 'NNP'),
#  ('RektResistance$hunt', 'NNP'),
#  ('is', 'VBZ'),
#  ('best$CoreGme', 'VBN'),
#  ('history', 'NN'),
#  ('has', 'VBZ'),
#  ('moved', 'VBN'),
#  ('AstaNew', 'NNP'),
#  ('project', 'NN'),
#  ('Linea', 'NNP'),
#  ('chain', 'NN'),
#  ('project', 'NN'),
#  ('Ethereum', 'NNP'),
#  ('are', 'VBP'),
#  ('is', 'VBZ'),
#  ('go', 'VB'),
#  ('x1001000', 'NNP'),
#  ('Take', 'NNP'),
#  ('look', 'NN'),
#  ('Foxy', 'NNP'),
#  ('Foxy', 'NNP'),
#  ('is', 'VBZ'),
#  ('meme', 'NN'),
#  ('chainCrypto', 'NN'),
#  ('was', 'VBD'),
#  ('meant', 'VBN'),
#  ('be', 'VB'),
#  ('wallet', 'NN'),
#  ('contractReal', 'NN'),
#  ('BTC', 'NNP'),
#  ('ETH', 'NNP'),
#  ('SOL', 'NNP'),
#  ('copiesApps', 'NN'),
#  ('workThats', 'VBZ'),
#  ('@zetablockchain', 'NN'),
#  ('delivers', 'NNS'),
#  ('Decentralized', 'VBD'),
#  ('validators', 'NNS'),
#  ('Built', 'VBN'),
#  ('teams', 'NNS'),
#  ('Native', 'VBP'),
#  ('crosschain', 'NN'),
#  ('bridges', 'VBZ'),
#  ('hacks', 'NNS'),
#  ('projects', 'NNS'),
#  ('are', 'VBP'),
#  ('Amana', 'NNP'),
#  ('Beam', 'NNP'),
#  ('DEX', 'NNP'),
#  ('moreThis', 'VB'),
#  ('isnt', 'NN'),
#  ('vaporware', 'NN'),
#  ('happening', 'VBG'),
#  ('devs', 'NN'),
#  ('flex', 'NN'),
#  ('is', 'VBZ'),
#  ('Build', 'NNP'),
#  ('Simpler', 'NNP'),
#  ('logic', 'NN'),
#  ('bugs', 'NNS'),
#  ('Safer', 'NNP'),
#  ('design', 'NN'),
#  ('brittle', 'NN'),
#  ('workaroundsFor', 'NN'),
#  ('users', 'NNS'),
#  ('Move', 'NNP'),
#  ('assets', 'NNS'),
#  ('stress', 'NN'),
#  ('Trust', 'NNP'),
#  ('crosschain', 'NN'),
#  ('apps', 'NN'),
#  ('Finally', 'NNP'),
#  ('feel', 'VB'),
#  ('crypto', 'NN'),
#  ('click', 'NN'),
#  ('My', 'NNP'),
#  ('favorite', 'NN'),
#  ('momentSending', 'VBG'),
#  ('BTC', 'NNP'),
#  ('ETH', 'NNP'),
#  ('vault', 'NN'),
#  ('bridge', 'NN'),
#  ('felt', 'NNS'),
#  ('magicBut', 'NN'),
#  ('was', 'VBD'),
#  ('Zetas', 'NNP'),
#  ('Zeta', 'NNP'),
#  ('chain', 'NN'),
#  ('felt', 'VBD'),
#  ('islandBTC', 'NN'),
#  ('ETH', 'NNP'),
#  ('SOL', 'NNP'),
#  ('cornerPowerful', 'NN'),
#  ('bridges', 'NNS'),
#  ('trusted', 'VBD'),
#  ('way', 'NN'),
#  ('moveThen', 'VB'),
#  ('came', 'VBD'),
#  ('missing', 'VBG'),
#  ('pieceNot', 'NN'),
#  ('alt', 'NN'),
#  ('L1The', 'NNP'),
#  ('Universal', 'NNP'),
#  ('Blockchain@zetablockchain', 'NNP'),
#  ('connects', 'VBZ'),
#  ('nativelyAnd', 'VBP'),
#  ('experience', 'VBP'),
#  ('theres', 'VBZ'),
#  ('going', 'VBG'),
#  ('MultichainKaia', 'NNP'),
#  ('Community', 'NNP'),
#  ('Townhall', 'NNP'),
#  ('Kaias', 'NNP'),
#  ('USDT', 'NNP'),
#  ('Campaign', 'NNP'),
#  ('Stablecoin', 'NNP'),
#  ('Hackathon', 'NNP'),
#  ('KickoffXRP', 'NNP'),
#  ('SUIBullish', 'NNP'),
#  ('$LABS$ACH', 'NN'),
#  ('Futures', 'NNS'),
#  ('LONG', 'NNP'),
#  ('SetupEntry', 'NNP'),
#  ('00210Targets', 'VBZ'),
#  ('margin', 'NN'),
#  ('risk', 'NN'),
#  ('protecting', 'VBG'),
#  ('half', 'NN'),
#  ('capitalACH', 'NN'),
#  ('is', 'VBZ'),
#  ('forming', 'VBG'),
#  ('Ascending', 'NNP'),
#  ('Triangle', 'NNP'),
#  ('Price', 'NNP'),
#  ('is', 'VBZ'),
#  ('pressing', 'VBG'),
#  ('resistance', 'NN'),
#  ('breakout', 'NN'),
#  ('looks', 'VBZ'),
#  ('sleep', 'NN'),
#  ('NexulonAI', 'NNP'),
#  ('is', 'VBZ'),
#  ('$NEX', 'NNP'),
#  ('AI', 'NNP'),
#  ('nextgen', 'NN'),
#  ('crypto', 'NN'),
#  ('Crypto', 'NNP'),
#  ('Trends', 'NNP'),
#  ('Bitcoin', 'NNP'),
#  ('has', 'VBZ'),
#  ('stormed', 'VBN'),
#  ('$112000', 'NN'),
#  ('showing', 'VBG'),
#  ('staying', 'VBG'),
#  ('power', 'NN'),
#  ('Solana', 'NNP'),
#  ('steals', 'VBZ'),
#  ('spotlight', 'NN'),
#  ('percent', 'NN'),
#  ('jump', 'NN'),
#  ('Whispers', 'NNS'),
#  ('Fed', 'NNP'),
#  ('brightening', 'NN'),
#  ('outlook', 'NN'),
#  ('have', 'VBP'),
#  ('traders', 'NNS'),
#  ('buzzing', 'VBG'),
#  ('yearend', 'NN'),
#  ('target', 'NN'),
#  ('BTC', 'NNP'),
#  ('Interestingly', 'NNP'),
#  ('Bitcoin', 'NNP'),
#  ('whales', 'NNS'),
#  ('are', 'VBP'),
#  ('rotating', 'VBG'),
#  ('altcoins', 'NNS'),
#  ('Remittix', 'NNP'),
#  ('betting', 'VBG'),
#  ('realworld', 'NN'),
#  ('use', 'NN'),
#  ('cases', 'NNS'),
#  ('markets', 'NNS'),
#  ('heating', 'VBG'),
#  ('stay', 'NN'),
#  ('focused', 'VBD'),
#  ('launchcoin', 'NN'),
#  ('$launchcoin', 'NN'),
#  ('Just', 'NNP'),
#  ('chads', 'NNS'),
#  ('have', 'VBP'),
#  ('aped', 'VBN'),
#  ('LAUNCHCOIN', 'NNP'),
#  ('Current', 'NNP'),
#  ('market', 'NN'),
#  ('cap', 'NN'),
#  ('$584M', 'NN'),
#  ('liquidity', 'NN'),
#  ('SOL', 'NNP'),
#  ('$11M', 'VBD'),
#  ('Total', 'NNP'),
#  ('holders', 'NNS'),
#  ('Check', 'NNP'),
#  ('chart', 'NN'),
#  ('httpstco29z5k4oMRN', 'VBZ'),
#  ('Talk', 'NNP'),
#  ('@Bitcoinhabebe', 'NNP'),
#  ('@StalkHQ', 'NNP'),
#  ('@Wolfy_XBT', 'NNP'),
#  ('@winiam4444', 'NNP'),
#  ('@MiyaHedge', 'NNP'),
#  ('@TheDonOfApes', 'NNP'),
#  ('@fomI', 'NNP'),
#  ('want', 'VBP'),
#  ('appreciate', 'VB'),
#  ('thank', 'VB'),
#  ('God', 'NNP'),
#  ('using', 'VBG'),
#  ('@Trader_Natasha0', 'NN'),
#  ('help', 'VB'),
#  ('Im', 'NNP'),
#  ('saying', 'VBG'),
#  ('everyone', 'NN'),
#  ('invested', 'VBD'),
#  ('USD', 'NNP'),
#  ('today', 'NN'),
#  ('received', 'VBD'),
#  ('USD', 'NNP'),
#  ('Bitcoin', 'NNP'),
#  ('walletThe', 'NN'),
#  ('Gorilla', 'NNP'),
#  ('logo', 'NN'),
#  ('@bscscan', 'NNP'),
#  ('has', 'VBZ'),
#  ('been', 'VBN'),
#  ('updated', 'VBN'),
#  ('isnt', 'NN'),
#  ('look', 'NN'),
#  ('symbol', 'NN'),
#  ('evolution', 'NN'),
#  ('revolution', 'NN'),
#  ('growth', 'NN'),
#  ('world', 'NN'),
#  ('class', 'NN'),
#  ('community', 'NN'),
#  ('power', 'NN'),
#  ('Original', 'NNP'),
#  ('G', 'NNP'),
#  ('belong', 'VB'),
#  ('$GORILLA', 'VB'),
#  ('LFGorilla', 'NNP'),
#  ('Layer', 'NNP'),
#  ('httpsblockchainreporternetpepetooutpacedogecoininthenextmarketrallybutlayerbretthasbeentippedas2025s100xmemecoin',
#   'NN'),
#  ('$PEPE', 'NNP'),
#  ('$DOGEThe', 'NNP'),
#  ('question', 'NN'),
#  ('is', 'VBZ'),
#  ('does', 'VBZ'),
#  ('liquidity', 'NN'),
#  ('go', 'VBP'),
#  ('assets', 'NNS'),
#  ('ownership', 'NN'),
#  ('markets', 'NNS'),
#  ('is', 'VBZ'),
#  ('leg', 'NN'),
#  ('starts', 'VBZ'),
#  ('RWAs', 'NNP'),
#  ('are', 'VBP'),
#  ('set', 'VBN'),
#  ('lead', 'VB'),
#  ('$Vax', 'VB'),
#  ('stands', 'NNS'),
#  ('centerHeres', 'NNS'),
#  ('Pillars', 'NNP'),
#  ('is', 'VBZ'),
#  ('goto', 'NN'),
#  ('trendsDont', 'NN'),
#  ('chase', 'VB'),
#  ('pumps', 'NNS'),
#  ('hunt', 'NN'),
#  ('monsters$OCTA', 'NN'),
#  ('isnt', 'NN'),
#  ('hype', 'NN'),
#  ('infrastructureReal', 'NN'),
#  ('Real', 'NNP'),
#  ('products', 'NNS'),
#  ('Real', 'NNP'),
#  ('growth', 'NN'),
#  ('potentialDevs', 'VBP'),
#  ('shipping', 'VBG'),
#  ('Community', 'NNP'),
#  ('growingis', 'VBP'),
#  ('wave', 'NN'),
#  ('bullrun', 'NN'),
#  ('trending', 'VBG'),
#  ('Grayscale', 'NNP'),
#  ('stacking', 'VBG'),
#  ('BTC', 'NNP'),
#  ('$GROK25B$', 'NNP'),
#  ('is', 'VBZ'),
#  ('Solana', 'NNP'),
#  ('SOL', 'NNP'),
#  ('climbed', 'VBD'),
#  ('$21294', 'VB'),
#  ('smashing', 'VBG'),
#  ('resistance', 'NN'),
#  ('RSI', 'NNP'),
#  ('MACD', 'NNP'),
#  ('backing', 'VBG'),
#  ('rallyDeFi', 'NN'),
#  ('TVL', 'NNP'),
#  ('hit', 'VBD'),
#  ('Jan', 'NNP'),
#  ('ecosystem', 'NN'),
#  ('growth', 'NN'),
#  ('rising', 'VBG'),
#  ('adoptionAnalysts', 'NNS'),
#  ('are', 'VBP'),
#  ('buzzing', 'VBG'),
#  ('targets', 'NNS'),
#  ('$220$245', 'NN'),
#  ('forecasts', 'NNS'),
#  ('averaging', 'VBG'),
#  ('$500If', 'NN'),
#  ('holds', 'VBZ'),
#  ('$210', 'NN'),
#  ('see', 'VB'),
#  ('is', 'VBZ'),
#  ('buy', 'VB'),
#  ('SOLCheck', 'NNP'),
#  ('analysisPehle', 'NN'),
#  ('sirf', 'NN'),
#  ('BTC', 'NNP'),
#  ('tha', 'NN'),
#  ('ab', 'NN'),
#  ('portfolio', 'NN'),
#  ('GROK25B', 'NNP'),
#  ('aur', 'VBZ'),
#  ('profit', 'NN'),
#  ('sab', 'NN'),
#  ('keh', 'NN'),
#  ('raha', 'NN'),
#  ('haiSolana', 'NN'),
#  ('fail', 'VB'),
#  ('baby', 'NN'),
#  ('$Kori', 'NNP'),
#  ('$ASCN', 'NNP'),
#  ('ASCOM', 'NNP'),
#  ('La', 'NNP'),
#  ('tendance', 'NN'),
#  ('haussière', 'NN'),
#  ('actuellement', 'NN'),
#  ('très', 'NN'),
#  ('forte', 'NN'),
#  ('sur', 'NN'),
#  ('ASCOM', 'NNP'),
#  ('N', 'NNP'),
#  ('Tant', 'NNP'),
#  ('que', 'NN'),
#  ('le', 'NN'),
#  ('cours', 'NNS'),
#  ('se', 'VBP'),
#  ('au', 'NN'),
#  ('dessus', 'NN'),
#  ('support', 'NN'),
#  ('à', 'NN'),
#  ('pourrait', 'NN'),
#  ('chercher', 'NN'),
#  ('àWeb3', 'NN'),
#  ('did', 'VBD'),
#  ('Farmed', 'NNP'),
#  ('Mito', 'NNP'),
#  ('ETH', 'NNP'),
#  ('hours', 'NNS'),
#  ('get', 'VB'),
#  ('return', 'NN'),
#  ('Enough', 'NNP'),
#  ('is', 'VBZ'),
#  ('XRPIve', 'NNP'),
#  ('been', 'VBN'),
#  ('GBTCWe', 'NNP'),
#  ('have', 'VBP'),
#  ('been', 'VBN'),
#  ('June', 'NNP'),
#  ('have', 'VBP'),
#  ('seen', 'VBN'),
#  ('Is', 'VBZ'),
#  ('moment', 'NN'),
#  ('bitcoinYes', 'NN'),
#  ('CT', 'NNP'),
#  ('do', 'VBP'),
#  ('something', 'NN'),
#  ('is', 'VBZ'),
#  ('building', 'VBG'),
#  ('nextgen', 'NN'),
#  ('crypto', 'NN'),
#  ('ecosystem', 'NN'),
#  ('powering', 'VBG'),
#  ('AI', 'NNP'),
#  ('tools', 'NNS'),
#  ('wallet', 'NN'),
#  ('functions', 'NNS'),
#  ('governance', 'NN'),
#  ('getting', 'VBG'),
#  ('phase', 'NN'),
#  ('be', 'VB'),
#  ('moves', 'NNS'),
#  ('yearI', 'VBZ'),
#  ('@fxasofia', 'NN'),
#  ('Bitcoin', 'NNP'),
#  ('enthusiasts', 'NNS'),
#  ('beginners', 'NNS'),
#  ('Shes', 'NNP'),
#  ('trader', 'NN'),
#  ('help', 'VB'),
#  ('achieve', 'VB'),
#  ('goals遂に', 'NN'),
#  ('WSOT', 'NNP'),
#  ('世界大会スタートBYBIT', 'VBZ'),
#  ('参加はコチラhttpstcoka6InCKNm9BYBIT', 'NNP'),
#  ('新規登録は約３分です招待コードはコチラKAIUNhttpstcoT1gSFwCoXs開運鬼龍BTC', 'NNP'),
#  ('$MNT', 'NNP'),
#  ('token', 'NN'),
#  ('is', 'VBZ'),
#  ('trading', 'NN'),
#  ('BitfinexEnjoy', 'NNP'),
#  ('trading', 'NN'),
#  ('fees', 'NNS'),
#  ('fees', 'NNS'),
#  ('market', 'NN'),
#  ('makers', 'NNS'),
#  ('bps', 'NNS'),
#  ('market', 'NN'),
#  ('takersMore', 'NN'),
#  ('information', 'NN'),
#  ('listing', 'NN'),
#  ('herehttpstcoD1Dir16xrDGM', 'NN'),
#  ('@bitgetglobal', 'NNP'),
#  ('X', 'NNP'),
#  ('$SOL', 'NNP'),
#  ('X', 'NNP'),
#  ('$TROLLLets', 'VBZ'),
#  ('earn', 'VBP'),
#  ('joining', 'VBG'),
#  ('Binances', 'NNS'),
#  ('timelimited', 'VBD'),
#  ('campaign', 'NN'),
#  ('tokens', 'NNS'),
#  ('vesting', 'NN'),
#  ('schedule', 'NN'),
#  ('upcoming', 'VBG'),
#  ('unlocks', 'NNS'),
#  ('put', 'VB'),
#  ('pressure', 'NN'),
#  ('pricebut', 'NN'),
#  ('ensure', 'VB'),
#  ('ecosystem', 'NN'),
#  ('incentives', 'NNS'),
#  ('sense', 'NN'),
#  ('BuiltonSolayer', 'NNP'),
#  ('Altcoin', 'NNP'),
#  ('Season', 'NNP'),
#  ('Is', 'VBZ'),
#  ('Solayers', 'NNP'),
#  ('$LAYER', 'NNP'),
#  ('Token', 'NNP'),
#  ('httpswwwbinancecomjoinref427461807Solayers', 'NNS'),
#  ('LAYER', 'NNP'),
#  ('token', 'NN'),
#  ('has', 'VBZ'),
#  ('gained', 'VBN'),
#  ('attention', 'NN'),
#  ('Solanas', 'NNP'),
#  ('restaking', 'VBG'),
#  ('protocol', 'NN'),
#  ('compared', 'VBN'),
#  ('EigenLayer', 'NNP'),
#  ('Ethereum', 'NNP'),
#  ('multitoken', 'NN'),
#  ('system', 'NN'),
#  ('LAYER', 'NNP'),
#  ('sSOL', 'NN'),
#  ('sUSD', 'NN'),
#  ('AVS', 'NNP'),
#  ('tokens', 'VBZ'),
#  ('adds', 'VBZ'),
#  ('depth', 'NN'),
#  ('ecosystem', 'NN'),
#  ('InfiniSVM', 'NNP'),
#  ('hardwareaccelerated', 'VBD'),
#  ('architecture', 'NN'),
#  ('aims', 'NNS'),
#  ('push', 'VB'),
#  ('Solanas', 'NNP'),
#  ('performance', 'NN'),
#  ('furthertargeting', 'VBG'),
#  ('millions', 'NNS'),
#  ('TPS', 'NNP'),
#  ('Gbps', 'NNP'),
#  ('throughput', 'NN'),
#  ('LAYER', 'NNP'),
#  ('had', 'VBD'),
#  ('debut', 'NN'),
#  ('surging', 'VBG'),
#  ('ATH', 'NNP'),
#  ('$3', 'NNP'),
#  ('correcting', 'VBG'),
#  ('$060', 'NNP'),
#  ('today', 'NN'),
#  ('So', 'NNP'),
#  ('is', 'VBZ'),
#  ('LAYER', 'NNP'),
#  ('SOL', 'NNP'),
#  ('LAYER', 'NNP'),
#  ('meanwhile', 'NN'),
#  ('is', 'VBZ'),
#  ('governance', 'NN'),
#  ('utility', 'NN'),
#  ('tokenits', 'NNS'),
#  ('value', 'NN'),
#  ('depends', 'VBZ'),
#  ('adoption', 'NN'),
#  ('Solayer', 'NNP'),
#  ('achieves', 'VBZ'),
#  ('restaking', 'VBG'),
#  ('scaling', 'VBG'),
#  ('solutions', 'NNS'),
#  ('LAYERs', 'NNP'),
#  ('advantage', 'VBP'),
#  ('backers', 'NNS'),
#  ('tech', 'NNS'),
#  ('make', 'VBP'),
#  ('Solanaecosystem', 'NNP'),
#  ('plays', 'VBZ'),
#  ('bull', 'NN'),
#  ('run逢低去配置一些ETF预期的币种其中10月有结果的是SOLLTCXRPDOGEADA11月DOT12月SUI尽量抄底时间最近的币种True',
#   'NN'),
#  ('OGs', 'NNP'),
#  ('scooped', 'VBD'),
#  ('ADA', 'NNP'),
#  ('$GROK25B', 'NNP'),
#  ('factsIts', 'NN'),
#  ('$AUTOS', 'NNP'),
#  ('supported', 'VBN'),
#  ('world', 'NN'),
#  ('utility', 'NN'),
#  ('revenue', 'NN'),
#  ('supercar', 'NN'),
#  ('marketplace', 'NN'),
#  ('Garage', 'NNP'),
#  ('model', 'NN'),
#  ('built', 'VBN'),
#  ('term', 'NN'),
#  ('wealth', 'NN'),
#  ('BullishOnAUTOSWhether', 'NNP'),
#  ('youre', 'NN'),
#  ('artist', 'NN'),
#  ('collector', 'NN'),
#  ('NFTs', 'NNP'),
#  ('feels', 'NNS'),
#  ('gamechanger', 'NN'),
#  ('Check', 'VB'),
#  ('TRONEcoStar', 'NNP'),
#  ('AIpowered', 'NNP'),
#  ('tool', 'NN'),
#  ('makes', 'VBZ'),
#  ('NFT', 'NNP'),
#  ('creation', 'NN'),
#  ('way', 'NN'),
#  ('fun', 'NN'),
#  ('generate', 'VB'),
#  ('artwork', 'NN'),
#  ('NFT', 'NNP'),
#  ('info', 'NN'),
#  ('clicks', 'NNS'),
#  ('process', 'NN'),
#  ('is', 'VBZ'),
#  ('kind', 'NN'),
#  ('Im', 'NNP'),
#  ('giving', 'VBG'),
#  ('try', 'NN'),
#  ('NFT', 'NNP'),
#  ('Pump', 'NNP'),
#  ('cant', 'NN'),
#  ('wait', 'NN'),
#  ('see', 'VB'),
#  ('createThanks', 'VB'),
#  ('weer', 'NN'),
#  ('Je', 'NNP'),
#  ('hebt', 'NN'),
#  ('het', 'NN'),
#  ('vaker', 'NN'),
#  ('coins', 'NNS'),
#  ('Wil', 'NNP'),
#  ('je', 'NN'),
#  ('ook', 'NN'),
#  ('keer', 'NN'),
#  ('Renzo', 'NNP'),
#  ('Aevo', 'NNP'),
#  ('Tia', 'NNP'),
#  ('behandelenI', 'NN'),
#  ('got', 'VBD'),
#  ('access', 'NN'),
#  ('OI', 'NNP'),
#  ('change', 'NN'),
#  ('history', 'NN'),
#  ('saying', 'VBG'),
#  ('cos', 'NN'),
#  ('OI', 'NNP'),
#  ('is', 'VBZ'),
#  ('showing', 'VBG'),
#  ('calls', 'NNS'),
#  ('yesterday', 'NN'),
#  ('be', 'VB'),
#  ('MM', 'NNP'),
#  ('bought', 'VBD'),
#  ('thats', 'NNS'),
#  ('hedged', 'VBD'),
#  ('selling', 'VBG'),
#  ('shares', 'NNS'),
#  ('time', 'NN'),
#  ('Crypto', 'NNP'),
#  ('adoption', 'NN'),
#  ('Massive', 'NNP'),
#  ('impressions', 'NNS'),
#  ('be', 'VB'),
#  ('see', 'VB'),
#  ('playing', 'VBG'),
#  ('Presale', 'NNP'),
#  ('investors', 'NNS'),
#  ('investors', 'NNS'),
#  ('be', 'VB'),
#  ('holding', 'VBG'),
#  ('thinking', 'VBG'),
#  ('selling', 'VBG'),
#  ('is', 'VBZ'),
#  ('Imo', 'NNP'),
#  ('@worldlibertyfi', 'NNP'),
#  ('is', 'VBZ'),
#  ('trying', 'VBG'),
#  ('create', 'VB'),
#  ('something', 'NN'),
#  ('create', 'VB'),
#  ('$USD1', 'NN'),
#  ('Ohhh', 'NNP'),
#  ('snap', 'VBZ'),
#  ('Big', 'NNP'),
#  ('moves', 'NNS'),
#  ('incoming', 'VBG'),
#  ('Lets', 'NNP'),
#  ('get', 'VB'),
#  ('rolling', 'VBG'),
#  ('MC', 'NNP'),
#  ('make', 'VB'),
#  ('history', 'NN'),
#  ('turn', 'VB'),
#  ('dreams', 'NNS'),
#  ('reality', 'NN'),
#  ('Lets', 'NNP'),
#  ('goooo', 'VBZ'),
#  ('$POLLY', 'NNP'),
#  ('Launch', 'NNP'),
#  ('Date', 'NNP'),
#  ('August', 'NNP'),
#  ('Time', 'NNP'),
#  ('UTC', 'NNP'),
#  ('Network', 'NNP'),
#  ('@base', 'NNP'),
#  ('@ClizaSystems', 'NNP'),
#  ('Website', 'NNP'),
#  ('httpstcoDoOfqRdXbhCOMING', 'NN'),
#  ('SOON', 'NNP'),
#  ('Somewhere', 'NNP'),
#  ('mall', 'NN'),
#  ('Kenya', 'NNP'),
#  ('Bitcoin', 'NNP'),
#  ('ATM', 'NNP'),
#  ('is', 'VBZ'),
#  ('reloading', 'VBG'),
#  ('Dont', 'NNP'),
#  ('sleep', 'NN'),
#  ('NexulonAI', 'NNP'),
#  ('is', 'VBZ'),
#  ('$NEX', 'NNP'),
#  ('AI', 'NNP'),
#  ('nextgen', 'NN'),
#  ('crypto$AUTOS', 'NN'),
#  ('has', 'VBZ'),
#  ('been', 'VBN'),
#  ('holding', 'VBG'),
#  ('others', 'NNS'),
#  ('test', 'VBP'),
#  ('supportThe', 'NN'),
#  ('fundamentals', 'NNS'),
#  ('are', 'VBP'),
#  ('lining', 'VBG'),
#  ('momentumThis', 'NN'),
#  ('is', 'VBZ'),
#  ('type', 'NN'),
#  ('project', 'NN'),
#  ('built', 'VBN'),
#  ('outlast', 'VB'),
#  ('handsA', 'NN'),
#  ('congrats', 'NNS'),
#  ('partners', 'NNS'),
#  ('@PythNetwork', 'VBP'),
#  ('reaching', 'VBG'),
#  ('groundbreaking', 'VBG'),
#  ('milestone', 'NN'),
#  ('bring', 'VB'),
#  ('US', 'NNP'),
#  ('GDP', 'NNP'),
#  ('data', 'NNS'),
#  ('data', 'NNS'),
#  ('is', 'VBZ'),
#  ('Injective', 'NNP'),
#  ('ecosystemThe', 'NN'),
#  ('world', 'NN'),
#  ('is', 'VBZ'),
#  ('moving', 'VBG'),
#  ('TURBO', 'NNP'),
#  ('XA59P', 'NNP'),
#  ('FLOKI', 'NNP'),
#  ('Robinhood', 'NN'),
#  ('Lists', 'NNS'),
#  ('Toncoin', 'NNP'),
#  ('$TON', 'NN'),
#  ('US', 'NNP'),
#  ('Users', 'NNP'),
#  ('Toncoin', 'NNP'),
#  ('scored', 'VBD'),
#  ('win', 'NN'),
#  ('Robinhood', 'NNP'),
#  ('Crypto', 'NNP'),
#  ('adds', 'VBZ'),
#  ('TON', 'NNP'),
#  ('trading', 'NN'),
#  ('sparking', 'VBG'),
#  ('price', 'NN'),
#  ('rebound', 'NN'),
#  ('Robinhood', 'NNP'),
#  ('users', 'NNS'),
#  ('have', 'VBP'),
#  ('access', 'NN'),
#  ('Backed', 'VBN'),
#  ('Telegram', 'NNP'),
#  ('users', 'NNS'),
#  ('official', 'NN'),
#  ('blockchain', 'NN'),
#  ('$708M', 'NNP'),
#  ('stablecoin', 'NN'),
#  ('market', 'NN'),
#  ('cap', 'NN'),
#  ('Tether', 'NNP'),
#  ('partnership', 'NN'),
#  ('Institutional', 'NNP'),
#  ('staking', 'VBG'),
#  ('treasury', 'NN'),
#  ('adoption', 'NN'),
#  ('growing', 'VBG'),
#  ('access', 'NN'),
#  ('fundamentals', 'NNS'),
#  ('TON', 'NNP'),
#  ('is', 'VBZ'),
#  ('gearing', 'VBG'),
#  ('breakout', 'NN'),
#  ('Altcoin', 'NNP'),
#  ('SeasonCheck', 'NNP'),
#  ('$core', 'NNP'),
#  ('$welfCelebrating', 'VBG'),
#  ('milestone', 'NN'),
#  ('today', 'NN'),
#  ('community', 'NN'),
#  ('hit', 'VBD'),
#  ('members', 'NNS'),
#  ('Discord', 'NNP'),
#  ('growth', 'NN'),
#  ('is', 'VBZ'),
#  ('result', 'NN'),
#  ('support', 'NN'),
#  ('engagement', 'NN'),
#  ('is', 'VBZ'),
#  ('beginning', 'NN'),
#  ('were', 'VBD'),
#  ('building', 'VBG'),
#  ('togetherWe', 'NN'),
#  ('had', 'VBD'),
#  ('time', 'NN'),
#  ('BUIDL', 'NNP'),
#  ('Europe', 'NNP'),
#  ('discussions', 'NNS'),
#  ('decentralized', 'VBN'),
#  ('AI', 'NNP'),
#  ('attention', 'NN'),
#  ('finance', 'NN'),
#  ('resonated', 'VBN'),
#  ('Were', 'NNP'),
#  ('excited', 'VBN'),
#  ('continue', 'VB'),
#  ('conversations', 'NNS'),
#  ('share', 'NN'),
#  ('insightsNext', 'NN'),
#  ('find', 'VB'),
#  ('European', 'NNP'),
#  ('Blockchain', 'NNP'),
#  ('Convention', 'NNP'),
#  ('Barcelona', 'NNP'),
#  ('Wed', 'NNP'),
#  ('love', 'NN'),
#  ('connect', 'VB'),
#  ('share', 'NN'),
#  ('Wallchain', 'NNP'),
#  ('future', 'NN'),
#  ('AttentionFIf', 'NNP'),
#  ('youre', 'NN'),
#  ('platform', 'NN'),
#  ('beginners', 'NNS'),
#  ('guide', 'VBP'),
#  ('is', 'VBZ'),
#  ('place', 'NN'),
#  ('start', 'VB'),
#  ('Learn', 'NNP'),
#  ('content', 'NN'),
#  ('generate', 'VB'),
#  ('rewards', 'NNS'),
#  ('Check', 'VB'),
#  ('link', 'NN'),
#  ('bio', 'NN'),
#  ...]

# %% [markdown]
# **Extracting Sentences with buy / sell keywords**

# %%
# Escape keywords in case of special characters
buy_pattern = r"\b(" + "|".join(map(re.escape, buy)) + r")\b"
sell_pattern = r"\b(" + "|".join(map(re.escape, sell)) + r")\b"

buy_regex = re.compile(buy_pattern, re.IGNORECASE)
sell_regex = re.compile(sell_pattern, re.IGNORECASE)

# %%
# Split into sentences
sentences = re.split(r'(?<=[.!?])\s+', text.strip())
results = []

def extract_buy_sell_sentences(text):
    # Split into sentences
    sentences = re.split(r'(?<=[.!?])\s+', text.strip())
    results = []
    for s in sentences:
        has_buy = bool(buy_regex.search(s))
        has_sell = bool(sell_regex.search(s))

        if has_buy or has_sell:
            label = "both" if has_buy and has_sell else "buy" if has_buy else "sell"
            results.append({"sentence": s,"label": label,"has_buy": has_buy,"has_sell": has_sell})
    return results
